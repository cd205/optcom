# %%
#!/usr/bin/env python
# IBKR Market Order Script for Option Spreads with Take Profit

import sqlite3
import pandas as pd
import datetime
from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract, ComboLeg
from ibapi.order import Order
from ibapi.utils import iswrapper
import time
import threading
import logging
import random

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

class IBWrapper(EWrapper):
    def __init__(self):
        super().__init__()
        self.next_order_id = None
        self.contract_details = {}
        self.mid_prices = {}
        self.combo_ids = {}

    @iswrapper
    def nextValidId(self, orderId: int):
        self.next_order_id = orderId
        logger.info(f"Next Valid Order ID: {orderId}")
    
    @iswrapper
    def tickPrice(self, reqId, tickType, price, attrib):
        if tickType in (1, 2):  # Bid or Ask
            if reqId not in self.mid_prices:
                self.mid_prices[reqId] = {"bid": None, "ask": None, "last": None, "model": None}
            self.mid_prices[reqId]["bid" if tickType == 1 else "ask"] = price
            logger.info(f"Received {'bid' if tickType == 1 else 'ask'} price for req_id {reqId}: {price}")
    
    @iswrapper
    def tickOptionComputation(self, reqId, tickType, tickAttrib, impliedVol, delta, optPrice, pvDividend, gamma, vega, theta, undPrice):
        if optPrice is not None and tickType in (12, 13):  # 12 = last price, 13 = model price
            if reqId not in self.mid_prices:
                self.mid_prices[reqId] = {"bid": None, "ask": None, "last": None, "model": None}
            self.mid_prices[reqId]["last" if tickType == 12 else "model"] = optPrice
            logger.info(f"Received {'last' if tickType == 12 else 'model'} price for req_id {reqId}: {optPrice}")

    @iswrapper
    def error(self, reqId, errorCode, errorString, advancedOrderRejectJson="", connectionClosed=False):
        logger.error(f"Error {reqId}: {errorCode} - {errorString}")
        
    @iswrapper
    def contractDetails(self, reqId, contractDetails):
        if reqId in self.combo_ids:
            self.combo_ids[reqId] = {
                "conId": contractDetails.contract.conId,
                "symbol": contractDetails.contract.symbol,
                "strike": contractDetails.contract.strike,
                "right": contractDetails.contract.right,
                "expiry": contractDetails.contract.lastTradeDateOrContractMonth
            }
            logger.info(f"Received contract details: {self.combo_ids[reqId]['symbol']} {self.combo_ids[reqId]['expiry']} {self.combo_ids[reqId]['strike']} {self.combo_ids[reqId]['right']}, conId: {self.combo_ids[reqId]['conId']}")

    @iswrapper
    def contractDetailsEnd(self, reqId):
        logger.info(f"Contract details request {reqId} completed")

    @iswrapper
    def openOrder(self, orderId, contract, order, orderState):
        logger.info(f"Order {orderId} status: {orderState.status}")

    @iswrapper
    def orderStatus(self, orderId, status, filled, remaining, avgFillPrice, permId, parentId, lastFillPrice, clientId, whyHeld, mktCapPrice):
        logger.info(f"Order {orderId} status update: {status}, filled: {filled}, remaining: {remaining}")

class IBClient(EClient):
    def __init__(self, wrapper):
        super().__init__(wrapper)

class IBApp(IBWrapper, IBClient):
    def __init__(self):
        IBWrapper.__init__(self)
        IBClient.__init__(self, wrapper=self)

    def create_option_contract(self, symbol, expiry, strike, right):
        contract = Contract()
        contract.symbol = symbol
        contract.secType = "OPT"
        contract.exchange = "SMART"
        contract.currency = "USD"
        contract.lastTradeDateOrContractMonth = expiry.replace("-", "")
        contract.strike = strike
        contract.right = right
        contract.multiplier = "100"
        
        logger.info(f"Created option contract: {symbol} {contract.lastTradeDateOrContractMonth} {strike} {right}")
        return contract
    
    def create_combo_contract(self, symbol, leg_contracts, contract_ids):
        contract = Contract()
        contract.symbol = symbol
        contract.secType = "BAG"
        contract.exchange = "SMART"
        contract.currency = "USD"
        
        buy_contract, sell_contract = leg_contracts
        buy_conId, sell_conId = contract_ids
        
        # Create legs
        leg1 = ComboLeg()
        leg1.conId = buy_conId
        leg1.ratio = 1
        leg1.action = "BUY"
        leg1.exchange = "SMART"
        
        leg2 = ComboLeg()
        leg2.conId = sell_conId
        leg2.ratio = 1
        leg2.action = "SELL"
        leg2.exchange = "SMART"
        
        contract.comboLegs = [leg1, leg2]
        logger.info(f"Created combo contract for {symbol} with 2 legs")
        return contract
    
    def create_limit_order(self, action, quantity, price, parent_id=None, transmit=True):
        order = Order()
        order.action = action
        order.orderType = "LMT"
        order.totalQuantity = quantity
        order.lmtPrice = price
        if parent_id is not None:
            order.parentId = parent_id
        order.transmit = transmit
        return order
    
    def get_contract_details(self, contract, req_id):
        self.combo_ids[req_id] = None
        self.reqContractDetails(req_id, contract)
        
        wait_time = 3
        start_time = time.time()
        while self.combo_ids[req_id] is None and time.time() - start_time < wait_time:
            time.sleep(0.1)
        return self.combo_ids.get(req_id)

    def get_price_data(self, contract, req_id):
        logger.info(f"Requesting market data for {contract.symbol} {contract.strike} {contract.right} (req_id: {req_id})")
        self.reqMktData(req_id, contract, "", False, False, [])
        time.sleep(5)
        
        if req_id in self.mid_prices:
            bid = self.mid_prices[req_id].get("bid")
            ask = self.mid_prices[req_id].get("ask")
            if bid is not None and ask is not None:
                logger.info(f"Received market data for req_id {req_id}: Bid={bid}, Ask={ask}")
            else:
                logger.warning(f"Incomplete market data for req_id {req_id}: Bid={bid}, Ask={ask}")
        else:
            logger.warning(f"No market data received for req_id {req_id}")

def get_strategies_for_date(date_str):
    conn = sqlite3.connect('database/option_strategies.db')
    target_date = pd.to_datetime(date_str)
    start_date = target_date.strftime('%Y-%m-%d')
    
    print('target_date: ', target_date)
    print('start_date: ', start_date)

    query = f"""
    SELECT * FROM option_strategies 
    WHERE date(scrape_date) = '{start_date}'
    AND timestamp_of_trigger IS NOT NULL
    AND (strategy_status IS NULL OR strategy_status != 'order placed with take profit')
    """
    
    df = pd.read_sql_query(query, conn)
    conn.close()
    return df

def get_last_prices_from_db(ticker, strike_sell, strike_buy, right):
    conn = sqlite3.connect('database/option_strategies.db')
    cursor = conn.cursor()
    
    # Query sell leg price
    sell_price = None
    cursor.execute("""
        SELECT last_price_when_checked FROM option_strategies 
        WHERE ticker = ? AND strike_sell = ? AND last_price_when_checked IS NOT NULL
        ORDER BY timestamp_of_price_when_last_checked DESC LIMIT 1
    """, (ticker, strike_sell))
    result = cursor.fetchone()
    if result: sell_price = result[0]
    
    # Query buy leg price
    buy_price = None
    cursor.execute("""
        SELECT last_price_when_checked FROM option_strategies 
        WHERE ticker = ? AND strike_buy = ? AND last_price_when_checked IS NOT NULL
        ORDER BY timestamp_of_price_when_last_checked DESC LIMIT 1
    """, (ticker, strike_buy))
    result = cursor.fetchone()
    if result: buy_price = result[0]
    
    conn.close()
    
    if sell_price: logger.info(f"Found historical sell price for {ticker} {strike_sell} {right}: {sell_price}")
    if buy_price: logger.info(f"Found historical buy price for {ticker} {strike_buy} {right}: {buy_price}")
    
    return sell_price, buy_price

def update_strategy_status(row_id, status, premium):
    conn = sqlite3.connect('database/option_strategies.db')
    cursor = conn.cursor()
    current_timestamp = int(time.time())
    
    try:
        cursor.execute("""
            UPDATE option_strategies 
            SET strategy_status = ?, premium_when_last_checked = ?, timestamp_of_order = ?
            WHERE id = ?
        """, (status, premium, current_timestamp, row_id))
        logger.info(f"Updated row {row_id} with status: {status}, premium: {premium}")
    except sqlite3.Error as e:
        logger.error(f"Database error updating strategy: {e}")
    
    conn.commit()
    conn.close()

def run_trading_app(target_date=None):
    if target_date is None:
        target_date = datetime.datetime.now().strftime('%Y-%m-%d')
    
    logger.info(f"Processing strategies for date: {target_date}")
    
    # Get strategies
    df = get_strategies_for_date(target_date)
    if df.empty:
        logger.info(f"No strategies found for {target_date}")
        return
    
    logger.info(f"Found {len(df)} strategies to process")
    
    # Connect to IBKR
    app = IBApp()
    client_id = random.randint(100, 9999)
    app.connect('127.0.0.1', 7497, client_id)
    
    ibkr_thread = threading.Thread(target=app.run)
    ibkr_thread.start()
    
    timeout = 10
    start_time = time.time()
    while not app.next_order_id and time.time() - start_time < timeout:
        time.sleep(0.1)
    
    if not app.next_order_id:
        logger.error("Failed to connect to IBKR or get valid order ID")
        app.disconnect()
        return
    
    # Process strategies
    for idx, row in df.iterrows():
        ticker = row['ticker']
        expiry = row['options_expiry_date']
        strategy_type = row['strategy_type']
        strike_buy = row['strike_buy']
        strike_sell = row['strike_sell']
        estimated_premium = row['estimated_premium']
        
        logger.info(f"Processing {strategy_type} for {ticker}, expiry {expiry}")
        
        # Set up contracts based on strategy type
        if strategy_type == 'Bear Call':
            sell_contract = app.create_option_contract(ticker, expiry, strike_sell, "C")
            buy_contract = app.create_option_contract(ticker, expiry, strike_buy, "C")
            combo_action = "SELL"
            take_profit_action = "BUY"
            option_right = "C"
        elif strategy_type == 'Bull Put':
            sell_contract = app.create_option_contract(ticker, expiry, strike_sell, "P")
            buy_contract = app.create_option_contract(ticker, expiry, strike_buy, "P")
            combo_action = "SELL"
            take_profit_action = "BUY"
            option_right = "P"
        else:
            logger.error(f"Unknown strategy type: {strategy_type}")
            continue
        
        # Get contract details
        req_id_sell = app.next_order_id
        app.next_order_id += 1
        sell_details = app.get_contract_details(sell_contract, req_id_sell)
        
        req_id_buy = app.next_order_id
        app.next_order_id += 1
        buy_details = app.get_contract_details(buy_contract, req_id_buy)
        
        if not sell_details or not buy_details:
            logger.error(f"Could not get contract details for one or both legs")
            update_strategy_status(row['id'], 'missing contract details', 0)
            continue
        
        # Get market data
        req_id_sell_price = app.next_order_id
        app.next_order_id += 1
        app.get_price_data(sell_contract, req_id_sell_price)
        
        req_id_buy_price = app.next_order_id
        app.next_order_id += 1
        app.get_price_data(buy_contract, req_id_buy_price)
        
        try:
            # Initialize prices
            sell_price = None
            buy_price = None
            
            # Try to get live prices
            if req_id_sell_price in app.mid_prices:
                prices = app.mid_prices[req_id_sell_price]
                if prices.get('bid') and prices.get('ask') and prices.get('bid') > 0 and prices.get('ask') > 0:
                    sell_price = (prices.get('bid') + prices.get('ask')) / 2
                elif prices.get('model') and prices.get('model') > 0:
                    sell_price = prices.get('model')
                elif prices.get('last') and prices.get('last') > 0:
                    sell_price = prices.get('last')
            
            if req_id_buy_price in app.mid_prices:
                prices = app.mid_prices[req_id_buy_price]
                if prices.get('bid') and prices.get('ask') and prices.get('bid') > 0 and prices.get('ask') > 0:
                    buy_price = (prices.get('bid') + prices.get('ask')) / 2
                elif prices.get('model') and prices.get('model') > 0:
                    buy_price = prices.get('model')
                elif prices.get('last') and prices.get('last') > 0:
                    buy_price = prices.get('last')
            
            # If live prices aren't available, get historical prices
            if not (sell_price and buy_price and sell_price > 0 and buy_price > 0):
                logger.info("Live market data unavailable, using historical prices")
                hist_sell_price, hist_buy_price = get_last_prices_from_db(
                    ticker, strike_sell, strike_buy, option_right)
                
                if hist_sell_price and hist_sell_price > 0:
                    sell_price = hist_sell_price
                
                if hist_buy_price and hist_buy_price > 0:
                    buy_price = hist_buy_price
            
            # Final validation check
            if not (sell_price and buy_price and sell_price > 0 and buy_price > 0):
                logger.error("No valid price data available for one or both legs")
                update_strategy_status(row['id'], 'no valid price data', 0)
                continue
            
            logger.info(f"Using prices - Sell: {sell_price}, Buy: {buy_price}")
            
            # Calculate premium
            premium_collected = sell_price - buy_price
            premium_collected_dollar = premium_collected * 100
            
            logger.info(f"Premium collected: {premium_collected} per share, ${premium_collected_dollar:.2f} per contract")
            logger.info(f"Estimated premium in database: ${estimated_premium:.2f} per contract")
            
            # Check if premium is sufficient
            if premium_collected_dollar < estimated_premium:
                update_strategy_status(row['id'], 'premium too low', premium_collected_dollar)
                continue
            
            # Create and place orders
            sell_conId = sell_details['conId']
            buy_conId = buy_details['conId']
            
            combo_contract = app.create_combo_contract(
                ticker, [buy_contract, sell_contract], [buy_conId, sell_conId])
            
            # Calculate prices
            take_profit_price = premium_collected / 2
            entry_limit_price = premium_collected
            
            # Parent order (entry)
            parent_order_id = app.next_order_id
            app.next_order_id += 1
            parent_order = app.create_limit_order(combo_action, 1, entry_limit_price, transmit=False)
            
            # Child order (take profit)
            take_profit_order_id = app.next_order_id
            app.next_order_id += 1
            take_profit_order = app.create_limit_order(
                take_profit_action, 1, take_profit_price, 
                parent_id=parent_order_id, transmit=True)
            
            # Place the orders
            app.placeOrder(parent_order_id, combo_contract, parent_order)
            app.placeOrder(take_profit_order_id, combo_contract, take_profit_order)
            
            logger.info(f"Placed orders: Entry {parent_order_id}, Take profit {take_profit_order_id}")
            update_strategy_status(row['id'], 'order placed with take profit', premium_collected_dollar)
            
        except Exception as e:
            logger.error(f"Error processing order: {str(e)}")
            update_strategy_status(row['id'], 'error', 0)
    
    # Cleanup
    time.sleep(3)
    app.disconnect()
    logger.info("Disconnected from IBKR")

if __name__ == "__main__":
    run_trading_app('2025-03-29')
# Out:
# /tmp/ipykernel_12288/205292301.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# 2025-03-31 15:41:46,576 - INFO - Processing strategies for date: 2025-03-29
# 2025-03-31 15:41:46,604 - INFO - Found 4 strategies to process
# 2025-03-31 15:41:46,627 - INFO - sent startApi
# 2025-03-31 15:41:46,632 - INFO - REQUEST startApi {}
# 2025-03-31 15:41:46,639 - INFO - SENDING startApi b'\x00\x00\x00\x0b71\x002\x002062\x00\x00'
# 2025-03-31 15:41:46,646 - INFO - ANSWER connectAck {}
# 2025-03-31 15:41:46,667 - INFO - Next Valid Order ID: 1
# 2025-03-31 15:41:46,707 - INFO - ANSWER managedAccounts {'accountsList': 'DU9233079'}
# 2025-03-31 15:41:46,715 - ERROR - Error -1: 0 - 2104
# 2025-03-31 15:41:46,722 - ERROR - Error -1: 0 - 2104
# 2025-03-31 15:41:46,724 - ERROR - Error -1: 0 - 2104
# 2025-03-31 15:41:46,736 - ERROR - Error -1: 0 - 2104
# 2025-03-31 15:41:46,738 - ERROR - Error -1: 0 - 2104
# 2025-03-31 15:41:46,741 - ERROR - Error -1: 0 - 2104
# 2025-03-31 15:41:46,743 - ERROR - Error -1: 0 - 2104
# 2025-03-31 15:41:46,761 - ERROR - Error -1: 0 - 2106
# 2025-03-31 15:41:46,765 - ERROR - Error -1: 0 - 2106
# 2025-03-31 15:41:46,773 - ERROR - Error -1: 0 - 2106
# 2025-03-31 15:41:46,768 - INFO - Processing Bull Put for GOOGL, expiry 2025-04-11
# 2025-03-31 15:41:46,782 - INFO - Created option contract: GOOGL 20250411 145.0 P
# 2025-03-31 15:41:46,784 - INFO - Created option contract: GOOGL 20250411 135.0 P
# 2025-03-31 15:41:46,796 - INFO - REQUEST reqContractDetails {'reqId': 1, 'contract': 125670304116752: 0,GOOGL,OPT,20250411,,145,P,100,SMART,,USD,,,False,,,,combo:}
# target_date:  2025-03-29 00:00:00
# start_date:  2025-03-29
# 2025-03-31 15:41:46,803 - INFO - SENDING reqContractDetails b'\x00\x00\x0099\x008\x001\x000\x00GOOGL\x00OPT\x0020250411\x00145.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# 2025-03-31 15:41:46,778 - ERROR - Error -1: 0 - 2158
# 2025-03-31 15:41:47,490 - INFO - Received contract details: GOOGL 20250411 145.0 P, conId: 764823038
# 2025-03-31 15:41:47,494 - INFO - Contract details request 1 completed
# 2025-03-31 15:41:47,522 - INFO - REQUEST reqContractDetails {'reqId': 2, 'contract': 125670304109216: 0,GOOGL,OPT,20250411,,135,P,100,SMART,,USD,,,False,,,,combo:}
# 2025-03-31 15:41:47,529 - INFO - SENDING reqContractDetails b'\x00\x00\x0099\x008\x002\x000\x00GOOGL\x00OPT\x0020250411\x00135.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# 2025-03-31 15:41:47,920 - INFO - Received contract details: GOOGL 20250411 135.0 P, conId: 764822893
# 2025-03-31 15:41:47,925 - INFO - Contract details request 2 completed
# 2025-03-31 15:41:47,945 - INFO - Requesting market data for GOOGL 145.0 P (req_id: 3)
# 2025-03-31 15:41:47,956 - INFO - REQUEST reqMktData {'reqId': 3, 'contract': 125670304116752: 0,GOOGL,OPT,20250411,,145,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-31 15:41:47,962 - INFO - SENDING reqMktData b'\x00\x00\x00=1\x0011\x003\x000\x00GOOGL\x00OPT\x0020250411\x00145.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-31 15:41:52,973 - WARNING - No market data received for req_id 3
# 2025-03-31 15:41:52,979 - INFO - Requesting market data for GOOGL 135.0 P (req_id: 4)
# 2025-03-31 15:41:52,981 - INFO - REQUEST reqMktData {'reqId': 4, 'contract': 125670304109216: 0,GOOGL,OPT,20250411,,135,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-31 15:41:52,983 - INFO - SENDING reqMktData b'\x00\x00\x00=1\x0011\x004\x000\x00GOOGL\x00OPT\x0020250411\x00135.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-31 15:41:53,427 - ERROR - Error -1: 0 - 2104
# 2025-03-31 15:41:53,578 - INFO - ANSWER marketDataType {'reqId': 3, 'marketDataType': 1}
# 2025-03-31 15:41:53,583 - INFO - ANSWER tickReqParams {'tickerId': 3, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 3}
# 2025-03-31 15:41:53,675 - INFO - ANSWER marketDataType {'reqId': 4, 'marketDataType': 1}
# 2025-03-31 15:41:53,676 - INFO - ANSWER tickReqParams {'tickerId': 4, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 3}
# 2025-03-31 15:41:53,683 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 8, 'size': Decimal('433')}
# 2025-03-31 15:41:53,697 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 45, 'value': '1743435615'}
# 2025-03-31 15:41:53,832 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 5, 'size': Decimal('1')}
# 2025-03-31 15:41:53,839 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 5, 'size': Decimal('1')}
# 2025-03-31 15:41:53,859 - INFO - Received bid price for req_id 3: 1.21
# 2025-03-31 15:41:53,871 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('210')}
# 2025-03-31 15:41:53,888 - INFO - Received ask price for req_id 3: 1.23
# 2025-03-31 15:41:53,892 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1353')}
# 2025-03-31 15:41:53,909 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('210')}
# 2025-03-31 15:41:53,923 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1353')}
# 2025-03-31 15:41:54,085 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 8, 'size': Decimal('101')}
# 2025-03-31 15:41:54,093 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 45, 'value': '1743435240'}
# 2025-03-31 15:41:54,128 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 5, 'size': Decimal('1')}
# 2025-03-31 15:41:54,130 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 5, 'size': Decimal('1')}
# 2025-03-31 15:41:54,140 - INFO - Received bid price for req_id 4: 0.28
# 2025-03-31 15:41:54,152 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1278')}
# 2025-03-31 15:41:54,159 - INFO - Received ask price for req_id 4: 0.29
# 2025-03-31 15:41:54,165 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('858')}
# 2025-03-31 15:41:54,183 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1278')}
# 2025-03-31 15:41:54,201 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('858')}
# 2025-03-31 15:41:54,567 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1400')}
# 2025-03-31 15:41:54,576 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('894')}
# 2025-03-31 15:41:54,586 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 32, 'value': 'ACINBQZWTHEJPDUS'}
# 2025-03-31 15:41:54,665 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('151')}
# 2025-03-31 15:41:54,674 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1244')}
# 2025-03-31 15:41:55,545 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1392')}
# 2025-03-31 15:41:55,552 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('979')}
# 2025-03-31 15:41:55,628 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('159')}
# 2025-03-31 15:41:55,629 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1206')}
# 2025-03-31 15:41:56,242 - INFO - Received model price for req_id 3: 1.2279577709064746
# 2025-03-31 15:41:56,248 - INFO - Received model price for req_id 4: 0.30002230109927935
# 2025-03-31 15:41:56,264 - INFO - Received last price for req_id 3: 1.190000057220459
# 2025-03-31 15:41:56,335 - INFO - Received last price for req_id 4: 0.30000001192092896
# 2025-03-31 15:41:56,530 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1308')}
# 2025-03-31 15:41:56,533 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1121')}
# 2025-03-31 15:41:56,627 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('9')}
# 2025-03-31 15:41:56,631 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1470')}
# 2025-03-31 15:41:56,637 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'Z'}
# 2025-03-31 15:41:57,148 - INFO - Received model price for req_id 3: 1.223449654636625
# 2025-03-31 15:41:57,153 - INFO - Received model price for req_id 4: 0.2988329511771082
# 2025-03-31 15:41:57,572 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1305')}
# 2025-03-31 15:41:57,583 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1036')}
# 2025-03-31 15:41:57,625 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('156')}
# 2025-03-31 15:41:57,645 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1234')}
# 2025-03-31 15:41:57,654 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'NBQZTPDU'}
# 2025-03-31 15:41:57,997 - INFO - Received market data for req_id 4: Bid=0.28, Ask=0.29
# 2025-03-31 15:41:58,003 - INFO - Using prices - Sell: 1.22, Buy: 0.28500000000000003
# 2025-03-31 15:41:58,011 - INFO - Premium collected: 0.9349999999999999 per share, $93.50 per contract
# 2025-03-31 15:41:58,017 - INFO - Estimated premium in database: $182.00 per contract
# 2025-03-31 15:41:58,025 - INFO - Updated row 58 with status: premium too low, premium: 93.5
# 2025-03-31 15:41:58,036 - INFO - Processing Bull Put for GOOGL, expiry 2025-04-17
# 2025-03-31 15:41:58,044 - INFO - Created option contract: GOOGL 20250417 145.0 P
# 2025-03-31 15:41:58,052 - INFO - Created option contract: GOOGL 20250417 135.0 P
# 2025-03-31 15:41:58,053 - INFO - REQUEST reqContractDetails {'reqId': 5, 'contract': 125670304116896: 0,GOOGL,OPT,20250417,,145,P,100,SMART,,USD,,,False,,,,combo:}
# 2025-03-31 15:41:58,061 - INFO - SENDING reqContractDetails b'\x00\x00\x0099\x008\x005\x000\x00GOOGL\x00OPT\x0020250417\x00145.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# 2025-03-31 15:41:58,155 - INFO - Received last price for req_id 3: 1.190000057220459
# 2025-03-31 15:41:58,161 - INFO - Received model price for req_id 3: 1.2257037127715587
# 2025-03-31 15:41:58,174 - INFO - Received last price for req_id 4: 0.30000001192092896
# 2025-03-31 15:41:58,180 - INFO - Received model price for req_id 4: 0.2994276261381934
# 2025-03-31 15:41:58,434 - INFO - Received contract details: GOOGL 20250417 145.0 P, conId: 726459145
# 2025-03-31 15:41:58,438 - INFO - Contract details request 5 completed
# 2025-03-31 15:41:58,473 - INFO - REQUEST reqContractDetails {'reqId': 6, 'contract': 125670304116752: 0,GOOGL,OPT,20250417,,135,P,100,SMART,,USD,,,False,,,,combo:}
# 2025-03-31 15:41:58,478 - INFO - SENDING reqContractDetails b'\x00\x00\x0099\x008\x006\x000\x00GOOGL\x00OPT\x0020250417\x00135.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# 2025-03-31 15:41:58,531 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1319')}
# 2025-03-31 15:41:58,540 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1063')}
# 2025-03-31 15:41:58,627 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('209')}
# 2025-03-31 15:41:58,631 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1237')}
# 2025-03-31 15:41:58,639 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'NBQZWTHPDU'}
# 2025-03-31 15:41:58,834 - INFO - Received contract details: GOOGL 20250417 135.0 P, conId: 726459076
# 2025-03-31 15:41:58,838 - INFO - Contract details request 6 completed
# 2025-03-31 15:41:58,889 - INFO - Requesting market data for GOOGL 145.0 P (req_id: 7)
# 2025-03-31 15:41:58,891 - INFO - REQUEST reqMktData {'reqId': 7, 'contract': 125670304116896: 0,GOOGL,OPT,20250417,,145,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-31 15:41:58,896 - INFO - SENDING reqMktData b'\x00\x00\x00=1\x0011\x007\x000\x00GOOGL\x00OPT\x0020250417\x00145.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-31 15:41:59,040 - INFO - Received model price for req_id 3: 1.2279577709064746
# 2025-03-31 15:41:59,047 - INFO - Received model price for req_id 4: 0.30002230109927935
# 2025-03-31 15:41:59,219 - INFO - ANSWER marketDataType {'reqId': 7, 'marketDataType': 1}
# 2025-03-31 15:41:59,221 - INFO - ANSWER tickReqParams {'tickerId': 7, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 3}
# 2025-03-31 15:41:59,318 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 8, 'size': Decimal('870')}
# 2025-03-31 15:41:59,325 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 45, 'value': '1743435674'}
# 2025-03-31 15:41:59,423 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 5, 'size': Decimal('2')}
# 2025-03-31 15:41:59,434 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 5, 'size': Decimal('2')}
# 2025-03-31 15:41:59,442 - INFO - Received bid price for req_id 7: 1.65
# 2025-03-31 15:41:59,455 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('246')}
# 2025-03-31 15:41:59,463 - INFO - Received ask price for req_id 7: 1.68
# 2025-03-31 15:41:59,482 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('1')}
# 2025-03-31 15:41:59,492 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('246')}
# 2025-03-31 15:41:59,502 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('1')}
# 2025-03-31 15:41:59,510 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 32, 'value': 'ACIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:41:59,523 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'Z'}
# 2025-03-31 15:41:59,530 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('283')}
# 2025-03-31 15:41:59,595 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1307')}
# 2025-03-31 15:41:59,607 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1004')}
# 2025-03-31 15:41:59,617 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('268')}
# 2025-03-31 15:41:59,624 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1148')}
# 2025-03-31 15:41:59,920 - INFO - Received model price for req_id 7: 1.7168180028033506
# 2025-03-31 15:41:59,933 - INFO - Received last price for req_id 7: 1.6399999856948853
# 2025-03-31 15:42:00,227 - INFO - Received model price for req_id 3: 1.223449654636625
# 2025-03-31 15:42:00,233 - INFO - Received model price for req_id 4: 0.2988329511771082
# 2025-03-31 15:42:00,235 - INFO - Received last price for req_id 3: 1.190000057220459
# 2025-03-31 15:42:00,239 - INFO - Received last price for req_id 4: 0.30000001192092896
# 2025-03-31 15:42:00,243 - INFO - Received model price for req_id 7: 1.682515582933509
# 2025-03-31 15:42:00,249 - INFO - Received last price for req_id 7: 1.6399999856948853
# 2025-03-31 15:42:00,388 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('152')}
# 2025-03-31 15:42:00,400 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('6')}
# 2025-03-31 15:42:00,403 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'IBZU'}
# 2025-03-31 15:42:00,584 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1312')}
# 2025-03-31 15:42:00,590 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('968')}
# 2025-03-31 15:42:00,597 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 33, 'value': 'CINBQZWTHPDU'}
# 2025-03-31 15:42:00,612 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('9')}
# 2025-03-31 15:42:00,615 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1345')}
# 2025-03-31 15:42:00,619 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'Z'}
# 2025-03-31 15:42:01,032 - INFO - Received model price for req_id 3: 1.2279577709064746
# 2025-03-31 15:42:01,035 - INFO - Received model price for req_id 4: 0.30002230109927935
# 2025-03-31 15:42:01,047 - INFO - Received model price for req_id 7: 1.686961470369625
# 2025-03-31 15:42:01,381 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('200')}
# 2025-03-31 15:42:01,383 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('4')}
# 2025-03-31 15:42:01,590 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1293')}
# 2025-03-31 15:42:01,598 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1028')}
# 2025-03-31 15:42:01,599 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 33, 'value': 'NBQZWTHPDU'}
# 2025-03-31 15:42:01,612 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('21')}
# 2025-03-31 15:42:01,619 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1256')}
# 2025-03-31 15:42:01,627 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'NZU'}
# 2025-03-31 15:42:02,287 - INFO - Received model price for req_id 3: 1.2257037127715513
# 2025-03-31 15:42:02,290 - INFO - Received model price for req_id 4: 0.299427626138191
# 2025-03-31 15:42:02,301 - INFO - Received last price for req_id 4: 0.30000001192092896
# 2025-03-31 15:42:02,318 - INFO - Received model price for req_id 7: 1.6847385261254975
# 2025-03-31 15:42:02,327 - INFO - Received last price for req_id 7: 1.6399999856948853
# 2025-03-31 15:42:02,385 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('203')}
# 2025-03-31 15:42:02,397 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('3')}
# 2025-03-31 15:42:02,402 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'BZ'}
# 2025-03-31 15:42:02,583 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1143')}
# 2025-03-31 15:42:02,589 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('9')}
# 2025-03-31 15:42:02,598 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1361')}
# 2025-03-31 15:42:02,616 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'Z'}
# 2025-03-31 15:42:03,280 - INFO - Received model price for req_id 3: 1.223449654636625
# 2025-03-31 15:42:03,282 - INFO - Received model price for req_id 4: 0.2988329511771082
# 2025-03-31 15:42:03,288 - INFO - Received model price for req_id 7: 1.682515582933509
# 2025-03-31 15:42:03,384 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('194')}
# 2025-03-31 15:42:03,390 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('7')}
# 2025-03-31 15:42:03,587 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1309')}
# 2025-03-31 15:42:03,594 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1200')}
# 2025-03-31 15:42:03,597 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 33, 'value': 'INBQZWTHPDU'}
# 2025-03-31 15:42:03,602 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1546')}
# 2025-03-31 15:42:03,789 - INFO - Received bid price for req_id 7: 1.66
# 2025-03-31 15:42:03,799 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('1')}
# 2025-03-31 15:42:03,807 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('1')}
# 2025-03-31 15:42:03,815 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('3')}
# 2025-03-31 15:42:03,824 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 32, 'value': 'U'}
# 2025-03-31 15:42:03,913 - INFO - Received market data for req_id 7: Bid=1.66, Ask=1.68
# 2025-03-31 15:42:03,922 - INFO - Requesting market data for GOOGL 135.0 P (req_id: 8)
# 2025-03-31 15:42:03,924 - INFO - REQUEST reqMktData {'reqId': 8, 'contract': 125670304116752: 0,GOOGL,OPT,20250417,,135,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-31 15:42:03,928 - INFO - SENDING reqMktData b'\x00\x00\x00=1\x0011\x008\x000\x00GOOGL\x00OPT\x0020250417\x00135.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-31 15:42:04,141 - INFO - ANSWER marketDataType {'reqId': 8, 'marketDataType': 1}
# 2025-03-31 15:42:04,145 - INFO - ANSWER tickReqParams {'tickerId': 8, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 3}
# 2025-03-31 15:42:04,235 - INFO - Received last price for req_id 3: 1.190000057220459
# 2025-03-31 15:42:04,242 - INFO - Received model price for req_id 3: 1.2279577709064746
# 2025-03-31 15:42:04,248 - INFO - Received last price for req_id 4: 0.30000001192092896
# 2025-03-31 15:42:04,251 - INFO - Received model price for req_id 4: 0.30002230109927935
# 2025-03-31 15:42:04,257 - INFO - Received last price for req_id 7: 1.6399999856948853
# 2025-03-31 15:42:04,260 - INFO - Received model price for req_id 7: 1.686961470369625
# 2025-03-31 15:42:04,314 - INFO - ANSWER tickString {'reqId': 8, 'tickType': 45, 'value': '1743435046'}
# 2025-03-31 15:42:04,376 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 5, 'size': Decimal('1')}
# 2025-03-31 15:42:04,384 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 5, 'size': Decimal('1')}
# 2025-03-31 15:42:04,388 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 8, 'size': Decimal('560')}
# 2025-03-31 15:42:04,397 - INFO - Received bid price for req_id 8: 0.46
# 2025-03-31 15:42:04,406 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('1133')}
# 2025-03-31 15:42:04,410 - INFO - Received ask price for req_id 8: 0.48
# 2025-03-31 15:42:04,418 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('903')}
# 2025-03-31 15:42:04,423 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('1133')}
# 2025-03-31 15:42:04,438 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('903')}
# 2025-03-31 15:42:04,444 - INFO - ANSWER tickString {'reqId': 8, 'tickType': 32, 'value': 'ACIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:04,447 - INFO - ANSWER tickString {'reqId': 8, 'tickType': 33, 'value': 'ACIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:04,514 - INFO - Received model price for req_id 8: 0.46308899963971545
# 2025-03-31 15:42:04,519 - INFO - Received last price for req_id 8: 0.5400000214576721
# 2025-03-31 15:42:04,592 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('1052')}
# 2025-03-31 15:42:04,594 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('555')}
# 2025-03-31 15:42:04,675 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1252')}
# 2025-03-31 15:42:04,678 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('720')}
# 2025-03-31 15:42:04,681 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 32, 'value': 'ACNBQZWTHEJPDUS'}
# 2025-03-31 15:42:04,682 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 33, 'value': 'NBQZWTHPDU'}
# 2025-03-31 15:42:04,684 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('327')}
# 2025-03-31 15:42:04,686 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('323')}
# 2025-03-31 15:42:04,687 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'CINBQZWTHEPDU'}
# 2025-03-31 15:42:04,689 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 33, 'value': 'CINBQZWTHEJPDUS'}
# 2025-03-31 15:42:04,800 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('33')}
# 2025-03-31 15:42:04,803 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('1')}
# 2025-03-31 15:42:04,806 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 32, 'value': 'INBQZTHJPDU'}
# 2025-03-31 15:42:04,810 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'Z'}
# 2025-03-31 15:42:05,069 - INFO - Received model price for req_id 3: 1.2302120388506088
# 2025-03-31 15:42:05,080 - INFO - Received model price for req_id 4: 0.3006169763742947
# 2025-03-31 15:42:05,092 - INFO - Received model price for req_id 7: 1.6891844158962255
# 2025-03-31 15:42:05,103 - INFO - Received model price for req_id 8: 0.47532024755470814
# 2025-03-31 15:42:05,496 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('1188')}
# 2025-03-31 15:42:05,499 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('532')}
# 2025-03-31 15:42:05,597 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1381')}
# 2025-03-31 15:42:05,601 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('755')}
# 2025-03-31 15:42:05,603 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('250')}
# 2025-03-31 15:42:05,604 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('707')}
# 2025-03-31 15:42:05,607 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'INBQZWTHPDU'}
# 2025-03-31 15:42:05,608 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 33, 'value': 'CINBQZWTMHEJPDUS'}
# 2025-03-31 15:42:05,799 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('39')}
# 2025-03-31 15:42:06,066 - INFO - Received last price for req_id 3: 1.190000057220459
# 2025-03-31 15:42:06,076 - INFO - Received last price for req_id 4: 0.30000001192092896
# 2025-03-31 15:42:06,080 - INFO - Received last price for req_id 7: 1.6399999856948853
# 2025-03-31 15:42:06,089 - INFO - Received last price for req_id 8: 0.5400000214576721
# 2025-03-31 15:42:06,500 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('1195')}
# 2025-03-31 15:42:06,504 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('539')}
# 2025-03-31 15:42:06,597 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('840')}
# 2025-03-31 15:42:06,601 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('292')}
# 2025-03-31 15:42:06,604 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('561')}
# 2025-03-31 15:42:06,609 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'INBQZWTMHPDU'}
# 2025-03-31 15:42:06,619 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 33, 'value': 'INBQZWTMHJPDUS'}
# 2025-03-31 15:42:06,797 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('42')}
# 2025-03-31 15:42:07,258 - INFO - Received model price for req_id 3: 1.2279577709064746
# 2025-03-31 15:42:07,261 - INFO - Received model price for req_id 4: 0.30002230109927935
# 2025-03-31 15:42:07,263 - INFO - Received model price for req_id 7: 1.686961470369625
# 2025-03-31 15:42:07,268 - INFO - Received model price for req_id 8: 0.47446584289075616
# 2025-03-31 15:42:07,499 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('1196')}
# 2025-03-31 15:42:07,502 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('349')}
# 2025-03-31 15:42:07,603 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1354')}
# 2025-03-31 15:42:07,605 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('631')}
# 2025-03-31 15:42:07,610 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('412')}
# 2025-03-31 15:42:07,614 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('215')}
# 2025-03-31 15:42:07,622 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'ACIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:07,626 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 33, 'value': 'CINBQZWTHEJPDU'}
# 2025-03-31 15:42:07,801 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('58')}
# 2025-03-31 15:42:08,092 - INFO - Received model price for req_id 3: 1.2324663584590314
# 2025-03-31 15:42:08,100 - INFO - Received model price for req_id 4: 0.3012116538778249
# 2025-03-31 15:42:08,106 - INFO - Received last price for req_id 3: 1.190000057220459
# 2025-03-31 15:42:08,110 - INFO - Received last price for req_id 4: 0.30000001192092896
# 2025-03-31 15:42:08,115 - INFO - Received last price for req_id 7: 1.6399999856948853
# 2025-03-31 15:42:08,117 - INFO - Received model price for req_id 7: 1.6914073614862932
# 2025-03-31 15:42:08,120 - INFO - Received model price for req_id 8: 0.4761746522186613
# 2025-03-31 15:42:08,128 - INFO - Received last price for req_id 8: 0.5400000214576721
# 2025-03-31 15:42:08,501 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('1174')}
# 2025-03-31 15:42:08,502 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('411')}
# 2025-03-31 15:42:08,600 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1335')}
# 2025-03-31 15:42:08,603 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1014')}
# 2025-03-31 15:42:08,609 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 32, 'value': 'ACINBQZWTHEJPDUS'}
# 2025-03-31 15:42:08,613 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('13')}
# 2025-03-31 15:42:08,615 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('90')}
# 2025-03-31 15:42:08,617 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 32, 'value': 'NBQZTJPDU'}
# 2025-03-31 15:42:08,619 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'NBZPU'}
# 2025-03-31 15:42:08,621 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('174')}
# 2025-03-31 15:42:08,622 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('720')}
# 2025-03-31 15:42:08,624 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'BQZWTHPDU'}
# 2025-03-31 15:42:08,625 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 33, 'value': 'CIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:08,938 - INFO - Received market data for req_id 8: Bid=0.46, Ask=0.48
# 2025-03-31 15:42:08,939 - INFO - Using prices - Sell: 1.67, Buy: 0.47
# 2025-03-31 15:42:08,943 - INFO - Premium collected: 1.2 per share, $120.00 per contract
# 2025-03-31 15:42:08,945 - INFO - Estimated premium in database: $206.00 per contract
# 2025-03-31 15:42:08,954 - INFO - Updated row 70 with status: premium too low, premium: 120.0
# 2025-03-31 15:42:08,972 - INFO - Processing Bull Put for NKE, expiry 2025-04-17
# 2025-03-31 15:42:08,978 - INFO - Created option contract: NKE 20250417 60.0 P
# 2025-03-31 15:42:08,987 - INFO - Created option contract: NKE 20250417 50.0 P
# 2025-03-31 15:42:08,988 - INFO - REQUEST reqContractDetails {'reqId': 9, 'contract': 125670304110848: 0,NKE,OPT,20250417,,60,P,100,SMART,,USD,,,False,,,,combo:}
# 2025-03-31 15:42:08,990 - INFO - SENDING reqContractDetails b'\x00\x00\x0069\x008\x009\x000\x00NKE\x00OPT\x0020250417\x0060.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# 2025-03-31 15:42:09,105 - INFO - Received model price for req_id 3: 1.2257037127715587
# 2025-03-31 15:42:09,107 - INFO - Received model price for req_id 4: 0.2994276261381934
# 2025-03-31 15:42:09,118 - INFO - Received model price for req_id 7: 1.6847385261255048
# 2025-03-31 15:42:09,123 - INFO - Received model price for req_id 8: 0.47361143822680396
# 2025-03-31 15:42:09,206 - INFO - Received bid price for req_id 3: 1.2
# 2025-03-31 15:42:09,209 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('358')}
# 2025-03-31 15:42:09,216 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('358')}
# 2025-03-31 15:42:09,219 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1649')}
# 2025-03-31 15:42:09,222 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'CNBQZTHPU'}
# 2025-03-31 15:42:09,224 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 33, 'value': 'ACIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:09,302 - INFO - Received bid price for req_id 7: 1.65
# 2025-03-31 15:42:09,313 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('49')}
# 2025-03-31 15:42:09,317 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('49')}
# 2025-03-31 15:42:09,321 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('446')}
# 2025-03-31 15:42:09,328 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 32, 'value': 'NBQZTHPU'}
# 2025-03-31 15:42:09,334 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'ACINBQZWTMHEJPDUS'}
# 2025-03-31 15:42:09,433 - INFO - Received contract details: NKE 20250417 60.0 P, conId: 723091092
# 2025-03-31 15:42:09,434 - INFO - Contract details request 9 completed
# 2025-03-31 15:42:09,500 - INFO - REQUEST reqContractDetails {'reqId': 10, 'contract': 125670304116896: 0,NKE,OPT,20250417,,50,P,100,SMART,,USD,,,False,,,,combo:}
# 2025-03-31 15:42:09,502 - INFO - SENDING reqContractDetails b'\x00\x00\x0079\x008\x0010\x000\x00NKE\x00OPT\x0020250417\x0050.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# 2025-03-31 15:42:09,509 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('997')}
# 2025-03-31 15:42:09,515 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('591')}
# 2025-03-31 15:42:09,616 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1312')}
# 2025-03-31 15:42:09,617 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1194')}
# 2025-03-31 15:42:09,621 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 33, 'value': 'CINBQZWTHPDUS'}
# 2025-03-31 15:42:09,836 - INFO - Received contract details: NKE 20250417 50.0 P, conId: 723978421
# 2025-03-31 15:42:09,837 - INFO - Contract details request 10 completed
# 2025-03-31 15:42:09,907 - INFO - Requesting market data for NKE 60.0 P (req_id: 11)
# 2025-03-31 15:42:09,917 - INFO - REQUEST reqMktData {'reqId': 11, 'contract': 125670304110848: 0,NKE,OPT,20250417,,60,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-31 15:42:09,927 - INFO - SENDING reqMktData b'\x00\x00\x00;1\x0011\x0011\x000\x00NKE\x00OPT\x0020250417\x0060.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-31 15:42:10,189 - INFO - Received last price for req_id 3: 1.190000057220459
# 2025-03-31 15:42:10,192 - INFO - Received model price for req_id 3: 1.2213191171194748
# 2025-03-31 15:42:10,211 - INFO - ANSWER marketDataType {'reqId': 11, 'marketDataType': 1}
# 2025-03-31 15:42:10,220 - INFO - Received model price for req_id 4: 0.2982382925129012
# 2025-03-31 15:42:10,229 - INFO - Received model price for req_id 7: 1.6802926657859076
# 2025-03-31 15:42:10,232 - INFO - Received model price for req_id 8: 0.47190262889889917
# 2025-03-31 15:42:10,245 - INFO - ANSWER tickReqParams {'tickerId': 11, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 3}
# 2025-03-31 15:42:10,252 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('620')}
# 2025-03-31 15:42:10,259 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('2306')}
# 2025-03-31 15:42:10,270 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'ACIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:10,280 - INFO - Received last price for req_id 4: 0.30000001192092896
# 2025-03-31 15:42:10,290 - INFO - Received last price for req_id 7: 1.6399999856948853
# 2025-03-31 15:42:10,297 - INFO - Received last price for req_id 8: 0.5400000214576721
# 2025-03-31 15:42:10,304 - INFO - ANSWER tickString {'reqId': 11, 'tickType': 45, 'value': '1743435644'}
# 2025-03-31 15:42:10,379 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 5, 'size': Decimal('1')}
# 2025-03-31 15:42:10,386 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 5, 'size': Decimal('1')}
# 2025-03-31 15:42:10,399 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 8, 'size': Decimal('2976')}
# 2025-03-31 15:42:10,405 - INFO - Received bid price for req_id 11: 0.55
# 2025-03-31 15:42:10,416 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('185')}
# 2025-03-31 15:42:10,419 - INFO - Received ask price for req_id 11: 0.56
# 2025-03-31 15:42:10,428 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 3, 'size': Decimal('10')}
# 2025-03-31 15:42:10,437 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('185')}
# 2025-03-31 15:42:10,443 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 3, 'size': Decimal('10')}
# 2025-03-31 15:42:10,448 - INFO - ANSWER tickString {'reqId': 11, 'tickType': 32, 'value': 'ACIXNBQZWTMHEPDU'}
# 2025-03-31 15:42:10,455 - INFO - ANSWER tickString {'reqId': 11, 'tickType': 33, 'value': 'Q'}
# 2025-03-31 15:42:10,465 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('83')}
# 2025-03-31 15:42:10,467 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('660')}
# 2025-03-31 15:42:10,468 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 32, 'value': 'CINBQZTHJPDU'}
# 2025-03-31 15:42:10,469 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'ACIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:10,504 - INFO - Received model price for req_id 11: 0.5648500858817697
# 2025-03-31 15:42:10,516 - INFO - Received last price for req_id 11: 0.5600000023841858
# 2025-03-31 15:42:10,557 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('1045')}
# 2025-03-31 15:42:10,563 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('634')}
# 2025-03-31 15:42:10,566 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1319')}
# 2025-03-31 15:42:10,576 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1199')}
# 2025-03-31 15:42:10,586 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 33, 'value': 'INBQZWTHPDUS'}
# 2025-03-31 15:42:10,859 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('119')}
# 2025-03-31 15:42:10,862 - INFO - ANSWER tickString {'reqId': 11, 'tickType': 32, 'value': 'CIXNBQZWTMHEPDU'}
# 2025-03-31 15:42:11,118 - INFO - Received model price for req_id 3: 1.2195108604914549
# 2025-03-31 15:42:11,134 - INFO - Received model price for req_id 4: 0.2976436349176667
# 2025-03-31 15:42:11,140 - INFO - Received model price for req_id 7: 1.6780697486383096
# 2025-03-31 15:42:11,147 - INFO - Received model price for req_id 8: 0.47104822423495074
# 2025-03-31 15:42:11,156 - INFO - Received model price for req_id 11: 0.5500646163315941
# 2025-03-31 15:42:11,165 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('708')}
# 2025-03-31 15:42:11,172 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('4402')}
# 2025-03-31 15:42:11,258 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('87')}
# 2025-03-31 15:42:11,267 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('766')}
# 2025-03-31 15:42:11,558 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('784')}
# 2025-03-31 15:42:11,659 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1196')}
# 2025-03-31 15:42:11,858 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('42')}
# 2025-03-31 15:42:11,862 - INFO - ANSWER tickString {'reqId': 11, 'tickType': 32, 'value': 'CINBQZTHPU'}
# 2025-03-31 15:42:12,122 - INFO - Received last price for req_id 3: 1.190000057220459
# 2025-03-31 15:42:12,126 - INFO - Received model price for req_id 3: 1.2213191171194748
# 2025-03-31 15:42:12,138 - INFO - Received model price for req_id 4: 0.2982382925129012
# 2025-03-31 15:42:12,140 - INFO - Received model price for req_id 7: 1.6802926657859076
# 2025-03-31 15:42:12,148 - INFO - Received model price for req_id 8: 0.47190262889889917
# 2025-03-31 15:42:12,154 - INFO - Received last price for req_id 11: 0.5600000023841858
# 2025-03-31 15:42:12,163 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('1049')}
# 2025-03-31 15:42:12,165 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('4822')}
# 2025-03-31 15:42:12,263 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('165')}
# 2025-03-31 15:42:12,270 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('394')}
# 2025-03-31 15:42:12,272 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 32, 'value': 'ACIXNBQZWTHJPDUS'}
# 2025-03-31 15:42:12,277 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'CINBQZWTHEJPDUS'}
# 2025-03-31 15:42:12,563 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('1064')}
# 2025-03-31 15:42:12,566 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('747')}
# 2025-03-31 15:42:12,664 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1263')}
# 2025-03-31 15:42:12,667 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1201')}
# 2025-03-31 15:42:12,674 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 32, 'value': 'AINBQZWTHEJPDUS'}
# 2025-03-31 15:42:12,859 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('20')}
# 2025-03-31 15:42:12,861 - INFO - ANSWER tickString {'reqId': 11, 'tickType': 32, 'value': 'INBQZTHJPU'}
# 2025-03-31 15:42:13,251 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('1058')}
# 2025-03-31 15:42:13,256 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('5277')}
# 2025-03-31 15:42:13,379 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('209')}
# 2025-03-31 15:42:13,382 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('408')}
# 2025-03-31 15:42:13,384 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 32, 'value': 'ACIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:13,388 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'INBQZWTMHJPDU'}
# 2025-03-31 15:42:13,561 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('733')}
# 2025-03-31 15:42:13,661 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1205')}
# 2025-03-31 15:42:14,064 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('19')}
# 2025-03-31 15:42:14,067 - INFO - ANSWER tickString {'reqId': 11, 'tickType': 32, 'value': 'INBQZTHPU'}
# 2025-03-31 15:42:14,078 - INFO - Received last price for req_id 3: 1.190000057220459
# 2025-03-31 15:42:14,082 - INFO - Received model price for req_id 11: 0.5522895943618469
# 2025-03-31 15:42:14,170 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('1128')}
# 2025-03-31 15:42:14,176 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('5432')}
# 2025-03-31 15:42:14,261 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('191')}
# 2025-03-31 15:42:14,264 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('205')}
# 2025-03-31 15:42:14,266 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'INBQZTMHPDUS'}
# 2025-03-31 15:42:14,362 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('8')}
# 2025-03-31 15:42:14,365 - INFO - ANSWER tickString {'reqId': 11, 'tickType': 32, 'value': 'I'}
# 2025-03-31 15:42:14,665 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1251')}
# 2025-03-31 15:42:14,669 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1265')}
# 2025-03-31 15:42:14,671 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 33, 'value': 'NBQZWTHPDU'}
# 2025-03-31 15:42:14,937 - INFO - Received market data for req_id 11: Bid=0.55, Ask=0.56
# 2025-03-31 15:42:14,938 - INFO - Requesting market data for NKE 50.0 P (req_id: 12)
# 2025-03-31 15:42:14,940 - INFO - REQUEST reqMktData {'reqId': 12, 'contract': 125670304116896: 0,NKE,OPT,20250417,,50,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-31 15:42:14,941 - INFO - SENDING reqMktData b'\x00\x00\x00;1\x0011\x0012\x000\x00NKE\x00OPT\x0020250417\x0050.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-31 15:42:15,044 - INFO - Received model price for req_id 3: 1.2195108604914549
# 2025-03-31 15:42:15,051 - INFO - Received model price for req_id 4: 0.2976436349176667
# 2025-03-31 15:42:15,061 - INFO - Received model price for req_id 7: 1.6780697486383096
# 2025-03-31 15:42:15,074 - INFO - Received model price for req_id 8: 0.47104822423495074
# 2025-03-31 15:42:15,091 - INFO - Received model price for req_id 11: 0.5500646163315923
# 2025-03-31 15:42:15,146 - INFO - ANSWER marketDataType {'reqId': 12, 'marketDataType': 1}
# 2025-03-31 15:42:15,148 - INFO - ANSWER tickReqParams {'tickerId': 12, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 3}
# 2025-03-31 15:42:15,246 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('985')}
# 2025-03-31 15:42:15,248 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('3556')}
# 2025-03-31 15:42:15,325 - INFO - ANSWER tickSize {'reqId': 12, 'tickType': 8, 'size': Decimal('1')}
# 2025-03-31 15:42:15,331 - INFO - Received bid price for req_id 12: 0.04
# 2025-03-31 15:42:15,336 - INFO - ANSWER tickSize {'reqId': 12, 'tickType': 0, 'size': Decimal('50')}
# 2025-03-31 15:42:15,339 - INFO - Received ask price for req_id 12: 0.07
# 2025-03-31 15:42:15,344 - INFO - ANSWER tickSize {'reqId': 12, 'tickType': 3, 'size': Decimal('5180')}
# 2025-03-31 15:42:15,353 - INFO - ANSWER tickSize {'reqId': 12, 'tickType': 0, 'size': Decimal('50')}
# 2025-03-31 15:42:15,363 - INFO - ANSWER tickSize {'reqId': 12, 'tickType': 3, 'size': Decimal('5180')}
# 2025-03-31 15:42:15,373 - INFO - ANSWER tickString {'reqId': 12, 'tickType': 32, 'value': 'N'}
# 2025-03-31 15:42:15,378 - INFO - ANSWER tickString {'reqId': 12, 'tickType': 33, 'value': 'ACIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:15,380 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('68')}
# 2025-03-31 15:42:15,394 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('827')}
# 2025-03-31 15:42:15,408 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 32, 'value': 'INBQZTHJPDU'}
# 2025-03-31 15:42:15,415 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'INBQZWTMHJPDUS'}
# 2025-03-31 15:42:15,421 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('210')}
# 2025-03-31 15:42:15,426 - INFO - ANSWER tickString {'reqId': 11, 'tickType': 32, 'value': 'INBQZWTHPDU'}
# 2025-03-31 15:42:15,554 - INFO - ANSWER tickSize {'reqId': 12, 'tickType': 3, 'size': Decimal('5098')}
# 2025-03-31 15:42:15,559 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('1034')}
# 2025-03-31 15:42:15,563 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('964')}
# 2025-03-31 15:42:15,731 - INFO - Received model price for req_id 12: 0.046806368143399134
# 2025-03-31 15:42:15,815 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1239')}
# 2025-03-31 15:42:15,821 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1230')}
# 2025-03-31 15:42:15,823 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 33, 'value': 'INBQZWTHPDUS'}
# 2025-03-31 15:42:16,061 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 8, 'size': Decimal('3119')}
# 2025-03-31 15:42:16,070 - INFO - Received model price for req_id 3: 1.2213191171194748
# 2025-03-31 15:42:16,076 - INFO - Received model price for req_id 4: 0.2982382925129012
# 2025-03-31 15:42:16,080 - INFO - Received last price for req_id 3: 1.190000057220459
# 2025-03-31 15:42:16,081 - INFO - Received model price for req_id 7: 1.6802926657859076
# 2025-03-31 15:42:16,083 - INFO - Received model price for req_id 8: 0.47190262889889917
# 2025-03-31 15:42:16,084 - INFO - Received last price for req_id 11: 0.5600000023841858
# 2025-03-31 15:42:16,161 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('865')}
# 2025-03-31 15:42:16,164 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('2690')}
# 2025-03-31 15:42:16,262 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('69')}
# 2025-03-31 15:42:16,272 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('808')}
# 2025-03-31 15:42:16,278 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 32, 'value': 'INBQZTHJPDUS'}
# 2025-03-31 15:42:16,362 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('206')}
# 2025-03-31 15:42:16,373 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 3, 'size': Decimal('155')}
# 2025-03-31 15:42:16,380 - INFO - ANSWER tickString {'reqId': 11, 'tickType': 33, 'value': 'NBQZTPDU'}
# 2025-03-31 15:42:16,460 - INFO - ANSWER tickSize {'reqId': 12, 'tickType': 3, 'size': Decimal('5181')}
# 2025-03-31 15:42:16,562 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('1066')}
# 2025-03-31 15:42:16,565 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('979')}
# 2025-03-31 15:42:17,004 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1247')}
# 2025-03-31 15:42:17,208 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('1838')}
# ...
# 2025-03-31 15:42:28,434 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 0, 'size': Decimal('368')}
# 2025-03-31 15:42:28,436 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 3, 'size': Decimal('81')}
# 2025-03-31 15:42:28,536 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 0, 'size': Decimal('879')}
# 2025-03-31 15:42:28,544 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 3, 'size': Decimal('649')}
# 2025-03-31 15:42:28,546 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('57')}
# 2025-03-31 15:42:28,554 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('3164')}
# 2025-03-31 15:42:28,558 - INFO - ANSWER tickString {'reqId': 8, 'tickType': 32, 'value': 'NBEPUS'}
# 2025-03-31 15:42:28,562 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('4807')}
# 2025-03-31 15:42:28,567 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 3, 'size': Decimal('209')}
# 2025-03-31 15:42:28,575 - INFO - ANSWER tickString {'reqId': 11, 'tickType': 33, 'value': 'CINBQZTHEPDUS'}
# 2025-03-31 15:42:28,941 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1095')}
# 2025-03-31 15:42:28,942 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1289')}
# 2025-03-31 15:42:29,035 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('164')}
# 2025-03-31 15:42:29,037 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1349')}
# 2025-03-31 15:42:29,045 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('213')}
# 2025-03-31 15:42:29,046 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('414')}
# 2025-03-31 15:42:29,235 - INFO - Received model price for req_id 3: 1.2142901414753111
# 2025-03-31 15:42:29,241 - INFO - Received model price for req_id 4: 0.2958596691524693
# 2025-03-31 15:42:29,242 - INFO - Received model price for req_id 7: 1.6714011209579673
# 2025-03-31 15:42:29,245 - INFO - Received model price for req_id 8: 0.4684850102430914
# 2025-03-31 15:42:29,248 - INFO - Received model price for req_id 11: 0.550579411979689
# 2025-03-31 15:42:29,254 - INFO - Received model price for req_id 12: 0.04632815731026688
# 2025-03-31 15:42:29,267 - INFO - Received model price for req_id 15: 3.3931939384777103
# 2025-03-31 15:42:29,274 - INFO - Received model price for req_id 16: 1.357060110137584
# 2025-03-31 15:42:29,338 - INFO - Received bid price for req_id 8: 0.45
# 2025-03-31 15:42:29,341 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('613')}
# 2025-03-31 15:42:29,343 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('613')}
# 2025-03-31 15:42:29,345 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('3286')}
# 2025-03-31 15:42:29,347 - INFO - ANSWER tickString {'reqId': 8, 'tickType': 32, 'value': 'CNBZTMHEPUS'}
# 2025-03-31 15:42:29,442 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 0, 'size': Decimal('240')}
# 2025-03-31 15:42:29,447 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 3, 'size': Decimal('44')}
# 2025-03-31 15:42:29,448 - INFO - ANSWER tickString {'reqId': 16, 'tickType': 33, 'value': 'INQZWTHJPDUS'}
# 2025-03-31 15:42:29,450 - INFO - ANSWER tickSize {'reqId': 12, 'tickType': 3, 'size': Decimal('5115')}
# 2025-03-31 15:42:29,454 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 0, 'size': Decimal('863')}
# 2025-03-31 15:42:29,458 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 3, 'size': Decimal('711')}
# 2025-03-31 15:42:29,536 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('5827')}
# 2025-03-31 15:42:29,936 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1063')}
# 2025-03-31 15:42:29,938 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1247')}
# 2025-03-31 15:42:30,037 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1215')}
# 2025-03-31 15:42:30,039 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('278')}
# 2025-03-31 15:42:30,042 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('260')}
# 2025-03-31 15:42:30,045 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'INBQZWTHJPDU'}
# 2025-03-31 15:42:30,198 - INFO - Received last price for req_id 3: 1.190000057220459
# 2025-03-31 15:42:30,203 - INFO - Received model price for req_id 3: 1.216015917813944
# 2025-03-31 15:42:30,207 - INFO - Received model price for req_id 4: 0.2964543211153375
# 2025-03-31 15:42:30,216 - INFO - Received model price for req_id 7: 1.6736239791091723
# 2025-03-31 15:42:30,230 - INFO - Received model price for req_id 8: 0.46933941490704334
# 2025-03-31 15:42:30,244 - INFO - Received last price for req_id 11: 0.5600000023841858
# 2025-03-31 15:42:30,247 - INFO - Received model price for req_id 15: 3.3847025990015
# 2025-03-31 15:42:30,262 - INFO - Received last price for req_id 15: 3.3499999046325684
# 2025-03-31 15:42:30,265 - INFO - Received model price for req_id 16: 1.3534700492956837
# 2025-03-31 15:42:30,276 - INFO - Received last price for req_id 16: 1.350000023841858
# 2025-03-31 15:42:30,340 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('2153')}
# 2025-03-31 15:42:30,344 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('2489')}
# 2025-03-31 15:42:30,348 - INFO - ANSWER tickString {'reqId': 8, 'tickType': 32, 'value': 'ACIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:30,440 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 0, 'size': Decimal('215')}
# 2025-03-31 15:42:30,443 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 3, 'size': Decimal('85')}
# 2025-03-31 15:42:30,447 - INFO - ANSWER tickString {'reqId': 16, 'tickType': 33, 'value': 'ACIXNBQZWTHEJPDUS'}
# 2025-03-31 15:42:30,461 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 0, 'size': Decimal('879')}
# 2025-03-31 15:42:30,466 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 3, 'size': Decimal('750')}
# 2025-03-31 15:42:30,537 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('5650')}
# 2025-03-31 15:42:30,932 - INFO - Received market data for req_id 16: Bid=1.34, Ask=1.39
# 2025-03-31 15:42:30,939 - INFO - Using prices - Sell: 3.4000000000000004, Buy: 1.365
# 2025-03-31 15:42:30,946 - INFO - Premium collected: 2.035 per share, $203.50 per contract
# 2025-03-31 15:42:30,940 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('1086')}
# 2025-03-31 15:42:30,961 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1352')}
# 2025-03-31 15:42:30,948 - INFO - Estimated premium in database: $246.00 per contract
# 2025-03-31 15:42:30,967 - INFO - Updated row 72 with status: premium too low, premium: 203.5
# 2025-03-31 15:42:31,041 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('94')}
# 2025-03-31 15:42:31,048 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('1316')}
# 2025-03-31 15:42:31,052 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('251')}
# 2025-03-31 15:42:31,055 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('316')}
# 2025-03-31 15:42:31,060 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'INBQZWTHEJPDUS'}
# 2025-03-31 15:42:31,068 - INFO - Received model price for req_id 3: 1.2142901414753111
# 2025-03-31 15:42:31,080 - INFO - Received model price for req_id 4: 0.2958596691524693
# 2025-03-31 15:42:31,089 - INFO - Received model price for req_id 7: 1.6714011209579673
# 2025-03-31 15:42:31,097 - INFO - Received model price for req_id 8: 0.4684850102430914
# 2025-03-31 15:42:31,099 - INFO - Received model price for req_id 11: 0.5483548030338175
# 2025-03-31 15:42:31,105 - INFO - Received model price for req_id 12: 0.04618247937206575
# 2025-03-31 15:42:31,340 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('1166')}
# 2025-03-31 15:42:31,341 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('1050')}
# 2025-03-31 15:42:31,351 - INFO - ANSWER tickString {'reqId': 8, 'tickType': 32, 'value': 'ACIXNBQZTMHEJPDUS'}
# 2025-03-31 15:42:31,439 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 0, 'size': Decimal('227')}
# 2025-03-31 15:42:31,443 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 3, 'size': Decimal('86')}
# 2025-03-31 15:42:31,450 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 0, 'size': Decimal('870')}
# 2025-03-31 15:42:31,453 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 3, 'size': Decimal('807')}
# 2025-03-31 15:42:31,541 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('6665')}
# 2025-03-31 15:42:31,543 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 3, 'size': Decimal('222')}
# 2025-03-31 15:42:31,546 - INFO - ANSWER tickString {'reqId': 11, 'tickType': 33, 'value': 'CIXNBQZTHEPDUS'}
# 2025-03-31 15:42:31,940 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('968')}
# 2025-03-31 15:42:31,942 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1364')}
# 2025-03-31 15:42:31,945 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 32, 'value': 'CINBQZWTHEPDU'}
# 2025-03-31 15:42:31,947 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 33, 'value': 'CINBQZWTHEJPDUS'}
# 2025-03-31 15:42:32,042 - INFO - Received bid price for req_id 7: 1.63
# 2025-03-31 15:42:32,046 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('256')}
# 2025-03-31 15:42:32,052 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('256')}
# 2025-03-31 15:42:32,061 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('1047')}
# 2025-03-31 15:42:32,073 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 32, 'value': 'ACNBQZTMEPUS'}
# 2025-03-31 15:42:32,075 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 33, 'value': 'ACIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:32,083 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('9')}
# 2025-03-31 15:42:32,088 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('3064')}
# 2025-03-31 15:42:32,095 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'Z'}
# 2025-03-31 15:42:32,148 - INFO - Received bid price for req_id 3: 1.19
# 2025-03-31 15:42:32,156 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('230')}
# 2025-03-31 15:42:32,157 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('230')}
# 2025-03-31 15:42:32,161 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('2988')}
# 2025-03-31 15:42:32,170 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'CNBQZTHPU'}
# 2025-03-31 15:42:32,176 - INFO - Received bid price for req_id 7: 1.64
# 2025-03-31 15:42:32,184 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('19')}
# 2025-03-31 15:42:32,187 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('19')}
# 2025-03-31 15:42:32,194 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('1084')}
# 2025-03-31 15:42:32,202 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 32, 'value': 'BQU'}
# 2025-03-31 15:42:32,250 - INFO - Received model price for req_id 3: 1.2091268416528351
# 2025-03-31 15:42:32,256 - INFO - Received model price for req_id 4: 0.2940757148551211
# 2025-03-31 15:42:32,260 - INFO - Received model price for req_id 7: 1.6647325465043457
# 2025-03-31 15:42:32,265 - INFO - Received last price for req_id 4: 0.30000001192092896
# 2025-03-31 15:42:32,272 - INFO - Received last price for req_id 7: 1.6399999856948853
# 2025-03-31 15:42:32,275 - INFO - Received model price for req_id 8: 0.4659219601253822
# 2025-03-31 15:42:32,279 - INFO - Received last price for req_id 8: 0.5400000214576721
# 2025-03-31 15:42:32,282 - INFO - Received last price for req_id 11: 0.5600000023841858
# 2025-03-31 15:42:32,290 - INFO - Received last price for req_id 15: 3.3499999046325684
# 2025-03-31 15:42:32,347 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('1982')}
# 2025-03-31 15:42:32,352 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('2314')}
# 2025-03-31 15:42:32,362 - INFO - ANSWER tickString {'reqId': 8, 'tickType': 32, 'value': 'ACIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:32,443 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 0, 'size': Decimal('255')}
# 2025-03-31 15:42:32,447 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 3, 'size': Decimal('80')}
# 2025-03-31 15:42:32,459 - INFO - ANSWER tickString {'reqId': 16, 'tickType': 33, 'value': 'CIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:32,461 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 0, 'size': Decimal('876')}
# 2025-03-31 15:42:32,474 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 3, 'size': Decimal('797')}
# 2025-03-31 15:42:32,540 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('6838')}
# 2025-03-31 15:42:32,541 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 3, 'size': Decimal('212')}
# 2025-03-31 15:42:32,945 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('985')}
# 2025-03-31 15:42:32,946 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1374')}
# 2025-03-31 15:42:32,951 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 32, 'value': 'INBQZWTHPDU'}
# 2025-03-31 15:42:32,955 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 33, 'value': 'CINBQZWTHEPDUS'}
# 2025-03-31 15:42:33,238 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('394')}
# 2025-03-31 15:42:33,255 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('5725')}
# 2025-03-31 15:42:33,265 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'ACIXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:33,266 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('14')}
# 2025-03-31 15:42:33,271 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('1220')}
# 2025-03-31 15:42:33,280 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 32, 'value': 'NZJPDU'}
# 2025-03-31 15:42:33,289 - INFO - Received ask price for req_id 16: 1.38
# 2025-03-31 15:42:33,297 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 3, 'size': Decimal('1')}
# 2025-03-31 15:42:33,301 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 0, 'size': Decimal('172')}
# 2025-03-31 15:42:33,305 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 3, 'size': Decimal('1')}
# 2025-03-31 15:42:33,310 - INFO - ANSWER tickString {'reqId': 16, 'tickType': 32, 'value': 'CXNBQZWTMHEJPDUS'}
# 2025-03-31 15:42:33,312 - INFO - ANSWER tickString {'reqId': 16, 'tickType': 33, 'value': 'U'}
# 2025-03-31 15:42:33,366 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('2064')}
# 2025-03-31 15:42:33,372 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('2325')}
# 2025-03-31 15:42:33,450 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 0, 'size': Decimal('427')}
# 2025-03-31 15:42:33,455 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 3, 'size': Decimal('688')}
# 2025-03-31 15:42:33,458 - INFO - ANSWER tickString {'reqId': 15, 'tickType': 32, 'value': 'CXNBQZWMHEJPDUS'}
# 2025-03-31 15:42:33,542 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('6863')}
# 2025-03-31 15:42:33,648 - INFO - Received bid price for req_id 3: 1.2
# 2025-03-31 15:42:33,651 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('14')}
# 2025-03-31 15:42:33,655 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('14')}
# 2025-03-31 15:42:33,661 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('5083')}
# 2025-03-31 15:42:33,668 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 32, 'value': 'NZU'}
# 2025-03-31 15:42:33,955 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('998')}
# 2025-03-31 15:42:33,956 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('1284')}
# 2025-03-31 15:42:33,962 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 32, 'value': 'CINBQZWTHEPDU'}
# 2025-03-31 15:42:33,970 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 33, 'value': 'INBQZWTHPDUS'}
# 2025-03-31 15:42:33,979 - INFO - disconnecting
# 2025-03-31 15:42:33,988 - INFO - ANSWER connectionClosed {}
# 2025-03-31 15:42:33,994 - INFO - Disconnected from IBKR
