# %%
#!/usr/bin/env python
# IBKR Market Order Script for Option Spreads with Take Profit

import sqlite3
import pandas as pd
import datetime
from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract, ComboLeg
from ibapi.order import Order
from ibapi.utils import iswrapper
import time
import threading
import logging
import random

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

class IBWrapper(EWrapper):
    def __init__(self):
        super().__init__()
        self.next_order_id = None
        self.contract_details = {}
        self.mid_prices = {}
        self.combo_ids = {}

    @iswrapper
    def nextValidId(self, orderId: int):
        self.next_order_id = orderId
        logger.info(f"Next Valid Order ID: {orderId}")
    
    @iswrapper
    def tickPrice(self, reqId, tickType, price, attrib):
        if tickType in (1, 2):  # Bid or Ask
            if reqId not in self.mid_prices:
                self.mid_prices[reqId] = {"bid": None, "ask": None, "last": None, "model": None}
            self.mid_prices[reqId]["bid" if tickType == 1 else "ask"] = price
            logger.info(f"Received {'bid' if tickType == 1 else 'ask'} price for req_id {reqId}: {price}")
    
    @iswrapper
    def tickOptionComputation(self, reqId, tickType, tickAttrib, impliedVol, delta, optPrice, pvDividend, gamma, vega, theta, undPrice):
        if optPrice is not None and tickType in (12, 13):  # 12 = last price, 13 = model price
            if reqId not in self.mid_prices:
                self.mid_prices[reqId] = {"bid": None, "ask": None, "last": None, "model": None}
            self.mid_prices[reqId]["last" if tickType == 12 else "model"] = optPrice
            logger.info(f"Received {'last' if tickType == 12 else 'model'} price for req_id {reqId}: {optPrice}")

    @iswrapper
    def error(self, reqId, errorCode, errorString, advancedOrderRejectJson="", connectionClosed=False):
        logger.error(f"Error {reqId}: {errorCode} - {errorString}")
        
    @iswrapper
    def contractDetails(self, reqId, contractDetails):
        if reqId in self.combo_ids:
            self.combo_ids[reqId] = {
                "conId": contractDetails.contract.conId,
                "symbol": contractDetails.contract.symbol,
                "strike": contractDetails.contract.strike,
                "right": contractDetails.contract.right,
                "expiry": contractDetails.contract.lastTradeDateOrContractMonth
            }
            logger.info(f"Received contract details: {self.combo_ids[reqId]['symbol']} {self.combo_ids[reqId]['expiry']} {self.combo_ids[reqId]['strike']} {self.combo_ids[reqId]['right']}, conId: {self.combo_ids[reqId]['conId']}")

    @iswrapper
    def contractDetailsEnd(self, reqId):
        logger.info(f"Contract details request {reqId} completed")

    @iswrapper
    def openOrder(self, orderId, contract, order, orderState):
        logger.info(f"Order {orderId} status: {orderState.status}")

    @iswrapper
    def orderStatus(self, orderId, status, filled, remaining, avgFillPrice, permId, parentId, lastFillPrice, clientId, whyHeld, mktCapPrice):
        logger.info(f"Order {orderId} status update: {status}, filled: {filled}, remaining: {remaining}")

class IBClient(EClient):
    def __init__(self, wrapper):
        super().__init__(wrapper)

class IBApp(IBWrapper, IBClient):
    def __init__(self):
        IBWrapper.__init__(self)
        IBClient.__init__(self, wrapper=self)

    def create_option_contract(self, symbol, expiry, strike, right):
        contract = Contract()
        contract.symbol = symbol
        contract.secType = "OPT"
        contract.exchange = "SMART"
        contract.currency = "USD"
        contract.lastTradeDateOrContractMonth = expiry.replace("-", "")
        contract.strike = strike
        contract.right = right
        contract.multiplier = "100"
        
        logger.info(f"Created option contract: {symbol} {contract.lastTradeDateOrContractMonth} {strike} {right}")
        return contract
    
    def create_combo_contract(self, symbol, leg_contracts, contract_ids):
        contract = Contract()
        contract.symbol = symbol
        contract.secType = "BAG"
        contract.exchange = "SMART"
        contract.currency = "USD"
        
        buy_contract, sell_contract = leg_contracts
        buy_conId, sell_conId = contract_ids
        
        # Create legs
        leg1 = ComboLeg()
        leg1.conId = buy_conId
        leg1.ratio = 1
        leg1.action = "BUY"
        leg1.exchange = "SMART"
        
        leg2 = ComboLeg()
        leg2.conId = sell_conId
        leg2.ratio = 1
        leg2.action = "SELL"
        leg2.exchange = "SMART"
        
        contract.comboLegs = [leg1, leg2]
        logger.info(f"Created combo contract for {symbol} with 2 legs")
        return contract
    
    def create_limit_order(self, action, quantity, price, parent_id=None, transmit=True):
        order = Order()
        order.action = action
        order.orderType = "LMT"
        order.totalQuantity = quantity
        order.lmtPrice = price
        if parent_id is not None:
            order.parentId = parent_id
        order.transmit = transmit
        return order
    
    def get_contract_details(self, contract, req_id):
        self.combo_ids[req_id] = None
        self.reqContractDetails(req_id, contract)
        
        wait_time = 3
        start_time = time.time()
        while self.combo_ids[req_id] is None and time.time() - start_time < wait_time:
            time.sleep(0.1)
        return self.combo_ids.get(req_id)

    def get_price_data(self, contract, req_id):
        logger.info(f"Requesting market data for {contract.symbol} {contract.strike} {contract.right} (req_id: {req_id})")
        self.reqMktData(req_id, contract, "", False, False, [])
        time.sleep(5)
        
        if req_id in self.mid_prices:
            bid = self.mid_prices[req_id].get("bid")
            ask = self.mid_prices[req_id].get("ask")
            if bid is not None and ask is not None:
                logger.info(f"Received market data for req_id {req_id}: Bid={bid}, Ask={ask}")
            else:
                logger.warning(f"Incomplete market data for req_id {req_id}: Bid={bid}, Ask={ask}")
        else:
            logger.warning(f"No market data received for req_id {req_id}")

def get_strategies_for_date(date_str):
    conn = sqlite3.connect('database/option_strategies.db')
    target_date = pd.to_datetime(date_str)
    start_date = target_date.strftime('%Y-%m-%d')
    
    print('target_date: ', target_date)
    print('start_date: ', start_date)

    query = f"""
    SELECT * FROM option_strategies 
    WHERE date(scrape_date) = '{start_date}'
    AND timestamp_of_trigger IS NOT NULL
    AND (strategy_status IS NULL OR strategy_status != 'order placed with take profit')
    """
    
    df = pd.read_sql_query(query, conn)
    conn.close()
    return df

def get_last_prices_from_db(ticker, strike_sell, strike_buy, right):
    conn = sqlite3.connect('database/option_strategies.db')
    cursor = conn.cursor()
    
    # Query sell leg price
    sell_price = None
    cursor.execute("""
        SELECT last_price_when_checked FROM option_strategies 
        WHERE ticker = ? AND strike_sell = ? AND last_price_when_checked IS NOT NULL
        ORDER BY timestamp_of_price_when_last_checked DESC LIMIT 1
    """, (ticker, strike_sell))
    result = cursor.fetchone()
    if result: sell_price = result[0]
    
    # Query buy leg price
    buy_price = None
    cursor.execute("""
        SELECT last_price_when_checked FROM option_strategies 
        WHERE ticker = ? AND strike_buy = ? AND last_price_when_checked IS NOT NULL
        ORDER BY timestamp_of_price_when_last_checked DESC LIMIT 1
    """, (ticker, strike_buy))
    result = cursor.fetchone()
    if result: buy_price = result[0]
    
    conn.close()
    
    if sell_price: logger.info(f"Found historical sell price for {ticker} {strike_sell} {right}: {sell_price}")
    if buy_price: logger.info(f"Found historical buy price for {ticker} {strike_buy} {right}: {buy_price}")
    
    return sell_price, buy_price

def update_strategy_status(row_id, status, premium):
    conn = sqlite3.connect('database/option_strategies.db')
    cursor = conn.cursor()
    current_timestamp = int(time.time())
    
    try:
        cursor.execute("""
            UPDATE option_strategies 
            SET strategy_status = ?, premium_when_last_checked = ?, timestamp_of_order = ?
            WHERE id = ?
        """, (status, premium, current_timestamp, row_id))
        logger.info(f"Updated row {row_id} with status: {status}, premium: {premium}")
    except sqlite3.Error as e:
        logger.error(f"Database error updating strategy: {e}")
    
    conn.commit()
    conn.close()

def run_trading_app(target_date=None):
    if target_date is None:
        target_date = datetime.datetime.now().strftime('%Y-%m-%d')
    
    logger.info(f"Processing strategies for date: {target_date}")
    
    # Get strategies
    df = get_strategies_for_date(target_date)
    if df.empty:
        logger.info(f"No strategies found for {target_date}")
        return
    
    logger.info(f"Found {len(df)} strategies to process")
    
    # Connect to IBKR
    app = IBApp()
    client_id = random.randint(100, 9999)
    app.connect('127.0.0.1', 7497, client_id)
    
    ibkr_thread = threading.Thread(target=app.run)
    ibkr_thread.start()
    
    timeout = 10
    start_time = time.time()
    while not app.next_order_id and time.time() - start_time < timeout:
        time.sleep(0.1)
    
    if not app.next_order_id:
        logger.error("Failed to connect to IBKR or get valid order ID")
        app.disconnect()
        return
    
    # Process strategies
    for idx, row in df.iterrows():
        ticker = row['ticker']
        expiry = row['options_expiry_date']
        strategy_type = row['strategy_type']
        strike_buy = row['strike_buy']
        strike_sell = row['strike_sell']
        estimated_premium = row['estimated_premium']
        
        logger.info(f"Processing {strategy_type} for {ticker}, expiry {expiry}")
        
        # Set up contracts based on strategy type
        if strategy_type == 'Bear Call':
            sell_contract = app.create_option_contract(ticker, expiry, strike_sell, "C")
            buy_contract = app.create_option_contract(ticker, expiry, strike_buy, "C")
            combo_action = "SELL"
            take_profit_action = "BUY"
            option_right = "C"
        elif strategy_type == 'Bull Put':
            sell_contract = app.create_option_contract(ticker, expiry, strike_sell, "P")
            buy_contract = app.create_option_contract(ticker, expiry, strike_buy, "P")
            combo_action = "SELL"
            take_profit_action = "BUY"
            option_right = "P"
        else:
            logger.error(f"Unknown strategy type: {strategy_type}")
            continue
        
        # Get contract details
        req_id_sell = app.next_order_id
        app.next_order_id += 1
        sell_details = app.get_contract_details(sell_contract, req_id_sell)
        
        req_id_buy = app.next_order_id
        app.next_order_id += 1
        buy_details = app.get_contract_details(buy_contract, req_id_buy)
        
        if not sell_details or not buy_details:
            logger.error(f"Could not get contract details for one or both legs")
            update_strategy_status(row['id'], 'missing contract details', 0)
            continue
        
        # Get market data
        req_id_sell_price = app.next_order_id
        app.next_order_id += 1
        app.get_price_data(sell_contract, req_id_sell_price)
        
        req_id_buy_price = app.next_order_id
        app.next_order_id += 1
        app.get_price_data(buy_contract, req_id_buy_price)
        
        try:
            # Initialize prices
            sell_price = None
            buy_price = None
            
            # Try to get live prices
            if req_id_sell_price in app.mid_prices:
                prices = app.mid_prices[req_id_sell_price]
                if prices.get('bid') and prices.get('ask') and prices.get('bid') > 0 and prices.get('ask') > 0:
                    sell_price = (prices.get('bid') + prices.get('ask')) / 2
                elif prices.get('model') and prices.get('model') > 0:
                    sell_price = prices.get('model')
                elif prices.get('last') and prices.get('last') > 0:
                    sell_price = prices.get('last')
            
            if req_id_buy_price in app.mid_prices:
                prices = app.mid_prices[req_id_buy_price]
                if prices.get('bid') and prices.get('ask') and prices.get('bid') > 0 and prices.get('ask') > 0:
                    buy_price = (prices.get('bid') + prices.get('ask')) / 2
                elif prices.get('model') and prices.get('model') > 0:
                    buy_price = prices.get('model')
                elif prices.get('last') and prices.get('last') > 0:
                    buy_price = prices.get('last')
            
            # If live prices aren't available, get historical prices
            if not (sell_price and buy_price and sell_price > 0 and buy_price > 0):
                logger.info("Live market data unavailable, using historical prices")
                hist_sell_price, hist_buy_price = get_last_prices_from_db(
                    ticker, strike_sell, strike_buy, option_right)
                
                if hist_sell_price and hist_sell_price > 0:
                    sell_price = hist_sell_price
                
                if hist_buy_price and hist_buy_price > 0:
                    buy_price = hist_buy_price
            
            # Final validation check
            if not (sell_price and buy_price and sell_price > 0 and buy_price > 0):
                logger.error("No valid price data available for one or both legs")
                update_strategy_status(row['id'], 'no valid price data', 0)
                continue
            
            logger.info(f"Using prices - Sell: {sell_price}, Buy: {buy_price}")
            
            # Calculate premium
            premium_collected = sell_price - buy_price
            premium_collected_dollar = premium_collected * 100
            
            logger.info(f"Premium collected: {premium_collected} per share, ${premium_collected_dollar:.2f} per contract")
            logger.info(f"Estimated premium in database: ${estimated_premium:.2f} per contract")
            
            # Check if premium is sufficient
            if premium_collected_dollar < estimated_premium:
                update_strategy_status(row['id'], 'premium too low', premium_collected_dollar)
                continue
            
            # Create and place orders
            sell_conId = sell_details['conId']
            buy_conId = buy_details['conId']
            
            combo_contract = app.create_combo_contract(
                ticker, [buy_contract, sell_contract], [buy_conId, sell_conId])
            
            # Calculate prices
            take_profit_price = premium_collected / 2
            entry_limit_price = premium_collected
            
            # Parent order (entry)
            parent_order_id = app.next_order_id
            app.next_order_id += 1
            parent_order = app.create_limit_order(combo_action, 1, entry_limit_price, transmit=False)
            
            # Child order (take profit)
            take_profit_order_id = app.next_order_id
            app.next_order_id += 1
            take_profit_order = app.create_limit_order(
                take_profit_action, 1, take_profit_price, 
                parent_id=parent_order_id, transmit=True)
            
            # Place the orders
            app.placeOrder(parent_order_id, combo_contract, parent_order)
            app.placeOrder(take_profit_order_id, combo_contract, take_profit_order)
            
            logger.info(f"Placed orders: Entry {parent_order_id}, Take profit {take_profit_order_id}")
            update_strategy_status(row['id'], 'order placed with take profit', premium_collected_dollar)
            
        except Exception as e:
            logger.error(f"Error processing order: {str(e)}")
            update_strategy_status(row['id'], 'error', 0)
    
    # Cleanup
    time.sleep(3)
    app.disconnect()
    logger.info("Disconnected from IBKR")

if __name__ == "__main__":
    run_trading_app('2025-03-29')
# Out:
# 2025-03-30 05:32:04,140 - INFO - Processing strategies for date: 2025-03-29
# 2025-03-30 05:32:04,148 - INFO - Found 4 strategies to process
# 2025-03-30 05:32:04,158 - INFO - sent startApi
# 2025-03-30 05:32:04,160 - INFO - REQUEST startApi {}
# 2025-03-30 05:32:04,161 - INFO - SENDING startApi b'\x00\x00\x00\x0b71\x002\x008543\x00\x00'
# 2025-03-30 05:32:04,162 - INFO - ANSWER connectAck {}
# 2025-03-30 05:32:04,183 - INFO - Next Valid Order ID: 1
# 2025-03-30 05:32:04,227 - ERROR - Error -1: 0 - 2104
# 2025-03-30 05:32:04,234 - ERROR - Error -1: 0 - 2104
# 2025-03-30 05:32:04,237 - ERROR - Error -1: 0 - 2104
# 2025-03-30 05:32:04,240 - ERROR - Error -1: 0 - 2104
# 2025-03-30 05:32:04,244 - ERROR - Error -1: 0 - 2104
# 2025-03-30 05:32:04,246 - INFO - ANSWER managedAccounts {'accountsList': 'DU9233079'}
# 2025-03-30 05:32:04,253 - ERROR - Error -1: 0 - 2104
# 2025-03-30 05:32:04,258 - ERROR - Error -1: 0 - 2104
# 2025-03-30 05:32:04,260 - ERROR - Error -1: 0 - 2104
# 2025-03-30 05:32:04,270 - ERROR - Error -1: 0 - 2106
# 2025-03-30 05:32:04,279 - ERROR - Error -1: 0 - 2106
# 2025-03-30 05:32:04,284 - ERROR - Error -1: 0 - 2106
# 2025-03-30 05:32:04,290 - ERROR - Error -1: 0 - 2158
# 2025-03-30 05:32:04,269 - INFO - Processing Bull Put for GOOGL, expiry 2025-04-11
# 2025-03-30 05:32:04,295 - INFO - Created option contract: GOOGL 20250411 145.0 P
# 2025-03-30 05:32:04,296 - INFO - Created option contract: GOOGL 20250411 135.0 P
# 2025-03-30 05:32:04,298 - INFO - REQUEST reqContractDetails {'reqId': 1, 'contract': 127107142574160: 0,GOOGL,OPT,20250411,,145,P,100,SMART,,USD,,,False,,,,combo:}
# 2025-03-30 05:32:04,299 - INFO - SENDING reqContractDetails b'\x00\x00\x0099\x008\x001\x000\x00GOOGL\x00OPT\x0020250411\x00145.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# target_date:  2025-03-29 00:00:00
# start_date:  2025-03-29
# 2025-03-30 05:32:04,701 - INFO - Received contract details: GOOGL 20250411 145.0 P, conId: 764823038
# 2025-03-30 05:32:04,706 - INFO - Contract details request 1 completed
# 2025-03-30 05:32:04,701 - INFO - REQUEST reqContractDetails {'reqId': 2, 'contract': 127107142574112: 0,GOOGL,OPT,20250411,,135,P,100,SMART,,USD,,,False,,,,combo:}
# 2025-03-30 05:32:04,716 - INFO - SENDING reqContractDetails b'\x00\x00\x0099\x008\x002\x000\x00GOOGL\x00OPT\x0020250411\x00135.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# 2025-03-30 05:32:05,019 - INFO - Received contract details: GOOGL 20250411 135.0 P, conId: 764822893
# 2025-03-30 05:32:05,025 - INFO - Requesting market data for GOOGL 145.0 P (req_id: 3)
# 2025-03-30 05:32:05,033 - INFO - REQUEST reqMktData {'reqId': 3, 'contract': 127107142574160: 0,GOOGL,OPT,20250411,,145,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-30 05:32:05,035 - INFO - SENDING reqMktData b'\x00\x00\x00=1\x0011\x003\x000\x00GOOGL\x00OPT\x0020250411\x00145.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-30 05:32:05,037 - INFO - Contract details request 2 completed
# 2025-03-30 05:32:05,383 - INFO - ANSWER marketDataType {'reqId': 3, 'marketDataType': 1}
# 2025-03-30 05:32:05,386 - INFO - ANSWER tickReqParams {'tickerId': 3, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 3}
# 2025-03-30 05:32:06,370 - INFO - Received model price for req_id 3: 1.0170742271636912
# 2025-03-30 05:32:07,164 - INFO - ANSWER tickString {'reqId': 3, 'tickType': 45, 'value': '0'}
# 2025-03-30 05:32:10,042 - WARNING - Incomplete market data for req_id 3: Bid=None, Ask=None
# 2025-03-30 05:32:10,044 - INFO - Requesting market data for GOOGL 135.0 P (req_id: 4)
# 2025-03-30 05:32:10,046 - INFO - REQUEST reqMktData {'reqId': 4, 'contract': 127107142574112: 0,GOOGL,OPT,20250411,,135,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-30 05:32:10,049 - INFO - SENDING reqMktData b'\x00\x00\x00=1\x0011\x004\x000\x00GOOGL\x00OPT\x0020250411\x00135.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-30 05:32:10,345 - INFO - ANSWER marketDataType {'reqId': 4, 'marketDataType': 1}
# 2025-03-30 05:32:10,346 - INFO - ANSWER tickReqParams {'tickerId': 4, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 3}
# 2025-03-30 05:32:11,175 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 5, 'size': Decimal('0')}
# 2025-03-30 05:32:11,191 - INFO - Received bid price for req_id 3: -1.0
# 2025-03-30 05:32:11,203 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:11,217 - INFO - Received ask price for req_id 3: -1.0
# 2025-03-30 05:32:11,228 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:11,240 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:11,244 - INFO - ANSWER tickSize {'reqId': 3, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:12,062 - INFO - ANSWER tickString {'reqId': 4, 'tickType': 45, 'value': '0'}
# 2025-03-30 05:32:15,060 - WARNING - No market data received for req_id 4
# 2025-03-30 05:32:15,072 - INFO - Live market data unavailable, using historical prices
# 2025-03-30 05:32:15,079 - INFO - Found historical sell price for GOOGL 145.0 P: -1.0
# 2025-03-30 05:32:15,088 - INFO - Found historical buy price for GOOGL 135.0 P: -1.0
# 2025-03-30 05:32:15,093 - ERROR - No valid price data available for one or both legs
# 2025-03-30 05:32:15,110 - INFO - Updated row 58 with status: no valid price data, premium: 0
# 2025-03-30 05:32:15,131 - INFO - Processing Bull Put for GOOGL, expiry 2025-04-17
# 2025-03-30 05:32:15,134 - INFO - Created option contract: GOOGL 20250417 145.0 P
# 2025-03-30 05:32:15,137 - INFO - Created option contract: GOOGL 20250417 135.0 P
# 2025-03-30 05:32:15,138 - INFO - REQUEST reqContractDetails {'reqId': 5, 'contract': 127107142573344: 0,GOOGL,OPT,20250417,,145,P,100,SMART,,USD,,,False,,,,combo:}
# 2025-03-30 05:32:15,140 - INFO - SENDING reqContractDetails b'\x00\x00\x0099\x008\x005\x000\x00GOOGL\x00OPT\x0020250417\x00145.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# 2025-03-30 05:32:15,514 - INFO - Received contract details: GOOGL 20250417 145.0 P, conId: 726459145
# 2025-03-30 05:32:15,518 - INFO - Contract details request 5 completed
# 2025-03-30 05:32:15,549 - INFO - REQUEST reqContractDetails {'reqId': 6, 'contract': 127107142574160: 0,GOOGL,OPT,20250417,,135,P,100,SMART,,USD,,,False,,,,combo:}
# 2025-03-30 05:32:15,558 - INFO - SENDING reqContractDetails b'\x00\x00\x0099\x008\x006\x000\x00GOOGL\x00OPT\x0020250417\x00135.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# 2025-03-30 05:32:15,914 - INFO - Received contract details: GOOGL 20250417 135.0 P, conId: 726459076
# 2025-03-30 05:32:15,933 - INFO - Contract details request 6 completed
# 2025-03-30 05:32:15,972 - INFO - Requesting market data for GOOGL 145.0 P (req_id: 7)
# 2025-03-30 05:32:15,973 - INFO - REQUEST reqMktData {'reqId': 7, 'contract': 127107142573344: 0,GOOGL,OPT,20250417,,145,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-30 05:32:15,976 - INFO - SENDING reqMktData b'\x00\x00\x00=1\x0011\x007\x000\x00GOOGL\x00OPT\x0020250417\x00145.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-30 05:32:16,177 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 5, 'size': Decimal('0')}
# 2025-03-30 05:32:16,196 - INFO - Received bid price for req_id 4: -1.0
# 2025-03-30 05:32:16,199 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:16,208 - INFO - Received ask price for req_id 4: -1.0
# 2025-03-30 05:32:16,220 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:16,228 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:16,233 - INFO - ANSWER tickSize {'reqId': 4, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:16,319 - INFO - ANSWER marketDataType {'reqId': 7, 'marketDataType': 1}
# 2025-03-30 05:32:16,326 - INFO - ANSWER tickReqParams {'tickerId': 7, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 3}
# 2025-03-30 05:32:18,012 - INFO - ANSWER tickString {'reqId': 7, 'tickType': 45, 'value': '0'}
# 2025-03-30 05:32:20,990 - WARNING - No market data received for req_id 7
# 2025-03-30 05:32:20,997 - INFO - Requesting market data for GOOGL 135.0 P (req_id: 8)
# 2025-03-30 05:32:21,014 - INFO - REQUEST reqMktData {'reqId': 8, 'contract': 127107142574160: 0,GOOGL,OPT,20250417,,135,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-30 05:32:21,036 - INFO - SENDING reqMktData b'\x00\x00\x00=1\x0011\x008\x000\x00GOOGL\x00OPT\x0020250417\x00135.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-30 05:32:21,280 - INFO - ANSWER marketDataType {'reqId': 8, 'marketDataType': 1}
# 2025-03-30 05:32:21,282 - INFO - ANSWER tickReqParams {'tickerId': 8, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 3}
# 2025-03-30 05:32:22,210 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 5, 'size': Decimal('0')}
# 2025-03-30 05:32:22,225 - INFO - Received bid price for req_id 7: -1.0
# 2025-03-30 05:32:22,234 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:22,241 - INFO - Received ask price for req_id 7: -1.0
# 2025-03-30 05:32:22,250 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:22,257 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:22,267 - INFO - ANSWER tickSize {'reqId': 7, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:23,136 - INFO - ANSWER tickString {'reqId': 8, 'tickType': 45, 'value': '0'}
# 2025-03-30 05:32:26,056 - WARNING - No market data received for req_id 8
# 2025-03-30 05:32:26,058 - INFO - Live market data unavailable, using historical prices
# 2025-03-30 05:32:26,065 - INFO - Found historical sell price for GOOGL 145.0 P: -1.0
# 2025-03-30 05:32:26,068 - INFO - Found historical buy price for GOOGL 135.0 P: -1.0
# 2025-03-30 05:32:26,074 - ERROR - No valid price data available for one or both legs
# 2025-03-30 05:32:26,079 - INFO - Updated row 70 with status: no valid price data, premium: 0
# 2025-03-30 05:32:26,089 - INFO - Processing Bull Put for NKE, expiry 2025-04-17
# 2025-03-30 05:32:26,098 - INFO - Created option contract: NKE 20250417 60.0 P
# 2025-03-30 05:32:26,100 - INFO - Created option contract: NKE 20250417 50.0 P
# 2025-03-30 05:32:26,108 - INFO - REQUEST reqContractDetails {'reqId': 9, 'contract': 127107142574784: 0,NKE,OPT,20250417,,60,P,100,SMART,,USD,,,False,,,,combo:}
# 2025-03-30 05:32:26,112 - INFO - SENDING reqContractDetails b'\x00\x00\x0069\x008\x009\x000\x00NKE\x00OPT\x0020250417\x0060.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# 2025-03-30 05:32:26,606 - INFO - Received contract details: NKE 20250417 60.0 P, conId: 723091092
# 2025-03-30 05:32:26,611 - INFO - Contract details request 9 completed
# 2025-03-30 05:32:26,618 - INFO - REQUEST reqContractDetails {'reqId': 10, 'contract': 127107142573344: 0,NKE,OPT,20250417,,50,P,100,SMART,,USD,,,False,,,,combo:}
# 2025-03-30 05:32:26,621 - INFO - SENDING reqContractDetails b'\x00\x00\x0079\x008\x0010\x000\x00NKE\x00OPT\x0020250417\x0050.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# 2025-03-30 05:32:26,953 - INFO - Received contract details: NKE 20250417 50.0 P, conId: 723978421
# 2025-03-30 05:32:26,994 - INFO - Contract details request 10 completed
# 2025-03-30 05:32:27,023 - INFO - Requesting market data for NKE 60.0 P (req_id: 11)
# 2025-03-30 05:32:27,032 - INFO - REQUEST reqMktData {'reqId': 11, 'contract': 127107142574784: 0,NKE,OPT,20250417,,60,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-30 05:32:27,035 - INFO - SENDING reqMktData b'\x00\x00\x00;1\x0011\x0011\x000\x00NKE\x00OPT\x0020250417\x0060.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-30 05:32:27,228 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 5, 'size': Decimal('0')}
# 2025-03-30 05:32:27,237 - INFO - Received bid price for req_id 8: -1.0
# 2025-03-30 05:32:27,240 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:27,252 - INFO - Received ask price for req_id 8: -1.0
# 2025-03-30 05:32:27,266 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:27,275 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:27,286 - INFO - ANSWER tickSize {'reqId': 8, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:27,351 - INFO - ANSWER marketDataType {'reqId': 11, 'marketDataType': 1}
# 2025-03-30 05:32:27,360 - INFO - ANSWER tickReqParams {'tickerId': 11, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 3}
# 2025-03-30 05:32:29,216 - INFO - ANSWER tickString {'reqId': 11, 'tickType': 45, 'value': '0'}
# 2025-03-30 05:32:32,045 - WARNING - No market data received for req_id 11
# 2025-03-30 05:32:32,051 - INFO - Requesting market data for NKE 50.0 P (req_id: 12)
# 2025-03-30 05:32:32,055 - INFO - REQUEST reqMktData {'reqId': 12, 'contract': 127107142573344: 0,NKE,OPT,20250417,,50,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-30 05:32:32,061 - INFO - SENDING reqMktData b'\x00\x00\x00;1\x0011\x0012\x000\x00NKE\x00OPT\x0020250417\x0050.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-30 05:32:32,273 - INFO - ANSWER marketDataType {'reqId': 12, 'marketDataType': 1}
# 2025-03-30 05:32:32,276 - INFO - ANSWER tickReqParams {'tickerId': 12, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 3}
# 2025-03-30 05:32:33,121 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 5, 'size': Decimal('0')}
# 2025-03-30 05:32:33,124 - INFO - Received bid price for req_id 11: -1.0
# 2025-03-30 05:32:33,136 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:33,140 - INFO - Received ask price for req_id 11: -1.0
# 2025-03-30 05:32:33,144 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:33,150 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:33,157 - INFO - ANSWER tickSize {'reqId': 11, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:34,100 - INFO - ANSWER tickString {'reqId': 12, 'tickType': 45, 'value': '0'}
# 2025-03-30 05:32:37,071 - WARNING - No market data received for req_id 12
# 2025-03-30 05:32:37,074 - INFO - Live market data unavailable, using historical prices
# 2025-03-30 05:32:37,079 - INFO - Found historical sell price for NKE 60.0 P: 65.8
# 2025-03-30 05:32:37,080 - INFO - Found historical buy price for NKE 50.0 P: 65.8
# 2025-03-30 05:32:37,081 - INFO - Using prices - Sell: 65.8, Buy: 65.8
# 2025-03-30 05:32:37,083 - INFO - Premium collected: 0.0 per share, $0.00 per contract
# 2025-03-30 05:32:37,084 - INFO - Estimated premium in database: $133.00 per contract
# 2025-03-30 05:32:37,092 - INFO - Updated row 71 with status: premium too low, premium: 0.0
# 2025-03-30 05:32:37,101 - INFO - Processing Bull Put for TSM, expiry 2025-04-17
# 2025-03-30 05:32:37,113 - INFO - Created option contract: TSM 20250417 155.0 P
# 2025-03-30 05:32:37,118 - INFO - Created option contract: TSM 20250417 145.0 P
# 2025-03-30 05:32:37,121 - INFO - REQUEST reqContractDetails {'reqId': 13, 'contract': 127107142574544: 0,TSM,OPT,20250417,,155,P,100,SMART,,USD,,,False,,,,combo:}
# 2025-03-30 05:32:37,123 - INFO - SENDING reqContractDetails b'\x00\x00\x0089\x008\x0013\x000\x00TSM\x00OPT\x0020250417\x00155.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# 2025-03-30 05:32:37,246 - INFO - Received contract details: TSM 20250417 155.0 P, conId: 723293901
# 2025-03-30 05:32:37,257 - INFO - Contract details request 13 completed
# 2025-03-30 05:32:37,329 - INFO - REQUEST reqContractDetails {'reqId': 14, 'contract': 127107142574784: 0,TSM,OPT,20250417,,145,P,100,SMART,,USD,,,False,,,,combo:}
# 2025-03-30 05:32:37,331 - INFO - SENDING reqContractDetails b'\x00\x00\x0089\x008\x0014\x000\x00TSM\x00OPT\x0020250417\x00145.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x00\x00\x00'
# 2025-03-30 05:32:37,446 - INFO - Received contract details: TSM 20250417 145.0 P, conId: 723293770
# 2025-03-30 05:32:37,451 - INFO - Contract details request 14 completed
# 2025-03-30 05:32:37,533 - INFO - Requesting market data for TSM 155.0 P (req_id: 15)
# 2025-03-30 05:32:37,540 - INFO - REQUEST reqMktData {'reqId': 15, 'contract': 127107142574544: 0,TSM,OPT,20250417,,155,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-30 05:32:37,545 - INFO - SENDING reqMktData b'\x00\x00\x00<1\x0011\x0015\x000\x00TSM\x00OPT\x0020250417\x00155.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-30 05:32:37,647 - INFO - ANSWER tickReqParams {'tickerId': 15, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 0}
# 2025-03-30 05:32:37,653 - INFO - ANSWER marketDataType {'reqId': 15, 'marketDataType': 1}
# 2025-03-30 05:32:37,658 - INFO - Received bid price for req_id 15: -1.0
# 2025-03-30 05:32:37,662 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:37,665 - INFO - Received ask price for req_id 15: -1.0
# 2025-03-30 05:32:37,669 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:37,674 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:37,679 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:37,683 - INFO - ANSWER tickSize {'reqId': 15, 'tickType': 5, 'size': Decimal('0')}
# 2025-03-30 05:32:37,688 - INFO - ANSWER tickGeneric {'reqId': 15, 'tickType': 49, 'value': 0.0}
# 2025-03-30 05:32:38,010 - INFO - ANSWER tickGeneric {'reqId': 15, 'tickType': 49, 'value': 0.0}
# 2025-03-30 05:32:38,142 - INFO - ANSWER tickSize {'reqId': 12, 'tickType': 5, 'size': Decimal('0')}
# 2025-03-30 05:32:38,151 - INFO - Received bid price for req_id 12: -1.0
# 2025-03-30 05:32:38,153 - INFO - ANSWER tickSize {'reqId': 12, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:38,159 - INFO - Received ask price for req_id 12: -1.0
# 2025-03-30 05:32:38,161 - INFO - ANSWER tickSize {'reqId': 12, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:38,163 - INFO - ANSWER tickSize {'reqId': 12, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:38,189 - INFO - ANSWER tickSize {'reqId': 12, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:42,560 - INFO - Received market data for req_id 15: Bid=-1.0, Ask=-1.0
# 2025-03-30 05:32:42,562 - INFO - Requesting market data for TSM 145.0 P (req_id: 16)
# 2025-03-30 05:32:42,564 - INFO - REQUEST reqMktData {'reqId': 16, 'contract': 127107142574784: 0,TSM,OPT,20250417,,145,P,100,SMART,,USD,,,False,,,,combo:, 'genericTickList': '', 'snapshot': False, 'regulatorySnapshot': False, 'mktDataOptions': []}
# 2025-03-30 05:32:42,572 - INFO - SENDING reqMktData b'\x00\x00\x00<1\x0011\x0016\x000\x00TSM\x00OPT\x0020250417\x00145.0\x00P\x00100\x00SMART\x00\x00USD\x00\x00\x000\x00\x000\x000\x00\x00'
# 2025-03-30 05:32:42,806 - INFO - ANSWER marketDataType {'reqId': 16, 'marketDataType': 1}
# 2025-03-30 05:32:42,818 - INFO - ANSWER tickReqParams {'tickerId': 16, 'minTick': 0.01, 'bboExchange': 'c70003', 'snapshotPermissions': 3}
# 2025-03-30 05:32:44,153 - INFO - ANSWER tickString {'reqId': 16, 'tickType': 45, 'value': '0'}
# 2025-03-30 05:32:47,584 - WARNING - No market data received for req_id 16
# 2025-03-30 05:32:47,586 - INFO - Live market data unavailable, using historical prices
# 2025-03-30 05:32:47,594 - INFO - Found historical sell price for TSM 155.0 P: 168.24
# 2025-03-30 05:32:47,604 - INFO - Found historical buy price for TSM 145.0 P: 168.24
# 2025-03-30 05:32:47,615 - INFO - Using prices - Sell: 168.24, Buy: 168.24
# 2025-03-30 05:32:47,625 - INFO - Premium collected: 0.0 per share, $0.00 per contract
# 2025-03-30 05:32:47,627 - INFO - Estimated premium in database: $246.00 per contract
# 2025-03-30 05:32:47,638 - INFO - Updated row 72 with status: premium too low, premium: 0.0
# 2025-03-30 05:32:48,132 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 5, 'size': Decimal('0')}
# 2025-03-30 05:32:48,141 - INFO - Received bid price for req_id 16: -1.0
# 2025-03-30 05:32:48,143 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:48,146 - INFO - Received ask price for req_id 16: -1.0
# 2025-03-30 05:32:48,156 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:48,158 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 0, 'size': Decimal('0')}
# 2025-03-30 05:32:48,166 - INFO - ANSWER tickSize {'reqId': 16, 'tickType': 3, 'size': Decimal('0')}
# 2025-03-30 05:32:50,675 - INFO - disconnecting
# 2025-03-30 05:32:50,681 - INFO - ANSWER connectionClosed {}
# 2025-03-30 05:32:50,687 - INFO - Disconnected from IBKR
